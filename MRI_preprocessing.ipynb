# %% [markdown]
# ## Import libraries

# %%
import SimpleITK as sitk
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shutil
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler

# %% [markdown]
# ## Find Path

# %%
f = sorted(os.listdir('picai_public_images_fold0'))
len(f)
# Out:
# 295

# %%
name_list = []
for i in f:
    temp_l = sorted(os.listdir(f'picai_public_images_fold0/{i}'))
    for j in temp_l:
        name_list.append(f'picai_public_images_fold0/{i}/{j}')
len(name_list)
# Out:
# 1500

# %%
name_list
# Out:
# ['picai_public_images_fold0/10000/10000_1000000_adc.mha',
#  'picai_public_images_fold0/10000/10000_1000000_cor.mha',
#  'picai_public_images_fold0/10000/10000_1000000_hbv.mha',
#  'picai_public_images_fold0/10000/10000_1000000_sag.mha',
#  'picai_public_images_fold0/10000/10000_1000000_t2w.mha',
#  'picai_public_images_fold0/10001/10001_1000001_adc.mha',
#  'picai_public_images_fold0/10001/10001_1000001_cor.mha',
#  'picai_public_images_fold0/10001/10001_1000001_hbv.mha',
#  'picai_public_images_fold0/10001/10001_1000001_sag.mha',
#  'picai_public_images_fold0/10001/10001_1000001_t2w.mha',
#  'picai_public_images_fold0/10003/10003_1000003_adc.mha',
#  'picai_public_images_fold0/10003/10003_1000003_cor.mha',
#  'picai_public_images_fold0/10003/10003_1000003_hbv.mha',
#  'picai_public_images_fold0/10003/10003_1000003_sag.mha',
#  'picai_public_images_fold0/10003/10003_1000003_t2w.mha',
#  'picai_public_images_fold0/10006/10006_1000006_adc.mha',
#  'picai_public_images_fold0/10006/10006_1000006_cor.mha',
#  'picai_public_images_fold0/10006/10006_1000006_hbv.mha',
#  'picai_public_images_fold0/10006/10006_1000006_sag.mha',
#  'picai_public_images_fold0/10006/10006_1000006_t2w.mha',
#  'picai_public_images_fold0/10017/10017_1000017_adc.mha',
#  'picai_public_images_fold0/10017/10017_1000017_cor.mha',
#  'picai_public_images_fold0/10017/10017_1000017_hbv.mha',
#  'picai_public_images_fold0/10017/10017_1000017_sag.mha',
#  'picai_public_images_fold0/10017/10017_1000017_t2w.mha',
#  'picai_public_images_fold0/10020/10020_1000020_adc.mha',
#  'picai_public_images_fold0/10020/10020_1000020_cor.mha',
#  'picai_public_images_fold0/10020/10020_1000020_hbv.mha',
#  'picai_public_images_fold0/10020/10020_1000020_sag.mha',
#  'picai_public_images_fold0/10020/10020_1000020_t2w.mha',
#  'picai_public_images_fold0/10022/10022_1000022_adc.mha',
#  'picai_public_images_fold0/10022/10022_1000022_cor.mha',
#  'picai_public_images_fold0/10022/10022_1000022_hbv.mha',
#  'picai_public_images_fold0/10022/10022_1000022_sag.mha',
#  'picai_public_images_fold0/10022/10022_1000022_t2w.mha',
#  'picai_public_images_fold0/10023/10023_1000023_adc.mha',
#  'picai_public_images_fold0/10023/10023_1000023_cor.mha',
#  'picai_public_images_fold0/10023/10023_1000023_hbv.mha',
#  'picai_public_images_fold0/10023/10023_1000023_sag.mha',
#  'picai_public_images_fold0/10023/10023_1000023_t2w.mha',
#  'picai_public_images_fold0/10027/10027_1000027_adc.mha',
#  'picai_public_images_fold0/10027/10027_1000027_cor.mha',
#  'picai_public_images_fold0/10964/10964_1000983_cor.mha',
#  'picai_public_images_fold0/10964/10964_1000983_hbv.mha',
#  'picai_public_images_fold0/10964/10964_1000983_sag.mha',
#  'picai_public_images_fold0/10964/10964_1000983_t2w.mha',
#  'picai_public_images_fold0/10978/10978_1000997_adc.mha',
#  'picai_public_images_fold0/10978/10978_1000997_cor.mha',
#  'picai_public_images_fold0/10978/10978_1000997_hbv.mha',
#  'picai_public_images_fold0/10978/10978_1000997_sag.mha',
#  'picai_public_images_fold0/10978/10978_1000997_t2w.mha',
#  'picai_public_images_fold0/10981/10981_1001000_adc.mha',
#  'picai_public_images_fold0/10981/10981_1001000_cor.mha',
#  'picai_public_images_fold0/10981/10981_1001000_hbv.mha',
#  'picai_public_images_fold0/10981/10981_1001000_sag.mha',
#  'picai_public_images_fold0/10981/10981_1001000_t2w.mha',
#  'picai_public_images_fold0/10982/10982_1001001_adc.mha',
#  'picai_public_images_fold0/10982/10982_1001001_cor.mha',
#  'picai_public_images_fold0/10982/10982_1001001_hbv.mha',
#  'picai_public_images_fold0/10982/10982_1001001_sag.mha',
#  'picai_public_images_fold0/10982/10982_1001001_t2w.mha',
#  'picai_public_images_fold0/10985/10985_1001004_adc.mha',
#  'picai_public_images_fold0/10985/10985_1001004_cor.mha',
#  'picai_public_images_fold0/10985/10985_1001004_hbv.mha',
#  'picai_public_images_fold0/10985/10985_1001004_sag.mha',
#  'picai_public_images_fold0/10985/10985_1001004_t2w.mha',
#  'picai_public_images_fold0/10990/10990_1001009_adc.mha',
#  'picai_public_images_fold0/10990/10990_1001009_cor.mha',
#  'picai_public_images_fold0/10990/10990_1001009_hbv.mha',
#  'picai_public_images_fold0/10990/10990_1001009_sag.mha',
#  'picai_public_images_fold0/10990/10990_1001009_t2w.mha',
#  ...]

# %%
grouped_files = {"adc": [], "cor": [], "hbv": [], "sag": [], "t2w": []}

for path in name_list:
    suffix = path.split('_')[-1].split('.')[0]
    grouped_files[suffix].append(path)

grouped_files = dict(grouped_files)
grouped_files
# Out:
# {'adc': ['picai_public_images_fold0/10000/10000_1000000_adc.mha',
#   'picai_public_images_fold0/10001/10001_1000001_adc.mha',
#   'picai_public_images_fold0/10003/10003_1000003_adc.mha',
#   'picai_public_images_fold0/10006/10006_1000006_adc.mha',
#   'picai_public_images_fold0/10017/10017_1000017_adc.mha',
#   'picai_public_images_fold0/10020/10020_1000020_adc.mha',
#   'picai_public_images_fold0/10022/10022_1000022_adc.mha',
#   'picai_public_images_fold0/10023/10023_1000023_adc.mha',
#   'picai_public_images_fold0/10027/10027_1000027_adc.mha',
#   'picai_public_images_fold0/10029/10029_1000029_adc.mha',
#   'picai_public_images_fold0/10032/10032_1000032_adc.mha',
#   'picai_public_images_fold0/10033/10033_1000033_adc.mha',
#   'picai_public_images_fold0/10035/10035_1000035_adc.mha',
#   'picai_public_images_fold0/10038/10038_1000038_adc.mha',
#   'picai_public_images_fold0/10040/10040_1000040_adc.mha',
#   'picai_public_images_fold0/10041/10041_1000041_adc.mha',
#   'picai_public_images_fold0/11222/11222_1001245_t2w.mha',
#   'picai_public_images_fold0/11231/11231_1001254_t2w.mha',
#   'picai_public_images_fold0/11234/11234_1001257_t2w.mha',
#   'picai_public_images_fold0/11248/11248_1001271_t2w.mha',
#   'picai_public_images_fold0/11249/11249_1001272_t2w.mha',
#   'picai_public_images_fold0/11259/11259_1001282_t2w.mha',
#   'picai_public_images_fold0/11260/11260_1001283_t2w.mha',
#   'picai_public_images_fold0/11266/11266_1001289_t2w.mha',
#   'picai_public_images_fold0/11285/11285_1001308_t2w.mha',
#   'picai_public_images_fold0/11288/11288_1001311_t2w.mha',
#   'picai_public_images_fold0/11294/11294_1001317_t2w.mha',
#   'picai_public_images_fold0/11304/11304_1001327_t2w.mha',
#   'picai_public_images_fold0/11307/11307_1001330_t2w.mha',
#   'picai_public_images_fold0/11313/11313_1001336_t2w.mha',
#   'picai_public_images_fold0/11322/11322_1001345_t2w.mha',
#   'picai_public_images_fold0/11330/11330_1001353_t2w.mha',
#   'picai_public_images_fold0/11332/11332_1001355_t2w.mha',
#   'picai_public_images_fold0/11334/11334_1001357_t2w.mha',
#   'picai_public_images_fold0/11335/11335_1001358_t2w.mha',
#   'picai_public_images_fold0/11341/11341_1001364_t2w.mha',
#   'picai_public_images_fold0/11346/11346_1001369_t2w.mha',
#   'picai_public_images_fold0/11351/11351_1001374_t2w.mha',
#   'picai_public_images_fold0/11352/11352_1001375_t2w.mha',
#   'picai_public_images_fold0/11353/11353_1001376_t2w.mha',
#   'picai_public_images_fold0/11377/11377_1001400_t2w.mha',
#   'picai_public_images_fold0/11383/11383_1001406_t2w.mha',
#   'picai_public_images_fold0/11383/11383_1001407_t2w.mha',
#   'picai_public_images_fold0/11386/11386_1001410_t2w.mha',
#   'picai_public_images_fold0/11389/11389_1001413_t2w.mha',
#   'picai_public_images_fold0/11391/11391_1001415_t2w.mha',
#   'picai_public_images_fold0/11392/11392_1001416_t2w.mha',
#   'picai_public_images_fold0/11400/11400_1001424_t2w.mha',
#   'picai_public_images_fold0/11420/11420_1001444_t2w.mha',
#   'picai_public_images_fold0/11425/11425_1001449_t2w.mha',
#   'picai_public_images_fold0/11427/11427_1001451_t2w.mha',
#   'picai_public_images_fold0/11442/11442_1001466_t2w.mha',
#   'picai_public_images_fold0/11451/11451_1001475_t2w.mha',
#   'picai_public_images_fold0/11461/11461_1001485_t2w.mha',
#   'picai_public_images_fold0/11467/11467_1001491_t2w.mha',
#   'picai_public_images_fold0/11469/11469_1001493_t2w.mha',
#   'picai_public_images_fold0/11471/11471_1001495_t2w.mha',
#   'picai_public_images_fold0/11473/11473_1001497_t2w.mha',
#   'picai_public_images_fold0/11474/11474_1001498_t2w.mha']}

# %%
grouped_files.keys()
# Out:
# dict_keys(['adc', 'cor', 'hbv', 'sag', 't2w'])

# %% [markdown]
# ## Show metadata

# %%
def show_metadata(g_file):
    for i in g_file:
        image = sitk.ReadImage(i)
    
        keys = image.GetMetaDataKeys()
    
        for key in keys:
            print(f"{key}: {image.GetMetaData(key)}")
        print('-' * 70)

# %%
show_metadata(grouped_files['cor'][:5])
# Out:
# 0008|0020: 2019-07-02
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10000
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000000
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 55
# PSAD_REPORT: nan
# PSA_REPORT: 7.7
# ----------------------------------------------------------------------
# 0008|0020: 2016-05-27
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10001
# 0010|0040: M
# 0010|1010: 064Y
# 0012|0062: YES
# 0020|000d: 1000001
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 102
# PSAD_REPORT: 0.09
# PSA_REPORT: 8.7
# ----------------------------------------------------------------------
# 0008|0020: 2019-04-05
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10003
# 0010|0040: M
# 0010|1010: 072Y
# 0012|0062: YES
# 0020|000d: 1000003
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 71.5
# PSAD_REPORT: nan
# PSA_REPORT: 13
# ----------------------------------------------------------------------
# 0008|0020: 2020-10-23
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10006
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000006
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 27
# PSAD_REPORT: 0.23
# PSA_REPORT: 6.2
# ----------------------------------------------------------------------
# 0008|0020: 2012-09-21
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10017
# 0010|0040: M
# 0010|1010: 067Y
# 0012|0062: YES
# 0020|000d: 1000017
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: nan
# PSAD_REPORT: nan
# PSA_REPORT: 5.5
# ----------------------------------------------------------------------

# %%
show_metadata(grouped_files['hbv'][:5])
# Out:
# 0008|0020: 2019-07-02
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10000
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0018|9087: 1400
# 0020|000d: 1000000
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 55
# PSAD_REPORT: nan
# PSA_REPORT: 7.7
# ----------------------------------------------------------------------
# 0008|0020: 2016-05-27
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10001
# 0010|0040: M
# 0010|1010: 064Y
# 0012|0062: YES
# 0018|9087: 1400
# 0020|000d: 1000001
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 102
# PSAD_REPORT: 0.09
# PSA_REPORT: 8.7
# ----------------------------------------------------------------------
# 0008|0020: 2019-04-05
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10003
# 0010|0040: M
# 0010|1010: 072Y
# 0012|0062: YES
# 0018|9087: 1400
# 0020|000d: 1000003
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 71.5
# PSAD_REPORT: nan
# PSA_REPORT: 13
# ----------------------------------------------------------------------
# 0008|0020: 2020-10-23
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10006
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0018|9087: 1400
# 0020|000d: 1000006
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 27
# PSAD_REPORT: 0.23
# PSA_REPORT: 6.2
# ----------------------------------------------------------------------
# 0008|0020: 2012-09-21
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10017
# 0010|0040: M
# 0010|1010: 067Y
# 0012|0062: YES
# 0018|9087: 1400
# 0020|000d: 1000017
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: nan
# PSAD_REPORT: nan
# PSA_REPORT: 5.5
# ----------------------------------------------------------------------

# %%
show_metadata(grouped_files['sag'][:5])
# Out:
# 0008|0020: 2019-07-02
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10000
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000000
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 55
# PSAD_REPORT: nan
# PSA_REPORT: 7.7
# ----------------------------------------------------------------------
# 0008|0020: 2016-05-27
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10001
# 0010|0040: M
# 0010|1010: 064Y
# 0012|0062: YES
# 0020|000d: 1000001
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 102
# PSAD_REPORT: 0.09
# PSA_REPORT: 8.7
# ----------------------------------------------------------------------
# 0008|0020: 2019-04-05
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10003
# 0010|0040: M
# 0010|1010: 072Y
# 0012|0062: YES
# 0020|000d: 1000003
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 71.5
# PSAD_REPORT: nan
# PSA_REPORT: 13
# ----------------------------------------------------------------------
# 0008|0020: 2020-10-23
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10006
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000006
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 27
# PSAD_REPORT: 0.23
# PSA_REPORT: 6.2
# ----------------------------------------------------------------------
# 0008|0020: 2012-09-21
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10017
# 0010|0040: M
# 0010|1010: 067Y
# 0012|0062: YES
# 0020|000d: 1000017
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: nan
# PSAD_REPORT: nan
# PSA_REPORT: 5.5
# ----------------------------------------------------------------------

# %%
show_metadata(grouped_files['t2w'][:5])
# Out:
# 0008|0020: 2019-07-02
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10000
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000000
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 55
# PSAD_REPORT: nan
# PSA_REPORT: 7.7
# ----------------------------------------------------------------------
# 0008|0020: 2016-05-27
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10001
# 0010|0040: M
# 0010|1010: 064Y
# 0012|0062: YES
# 0020|000d: 1000001
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 102
# PSAD_REPORT: 0.09
# PSA_REPORT: 8.7
# ----------------------------------------------------------------------
# 0008|0020: 2019-04-05
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10003
# 0010|0040: M
# 0010|1010: 072Y
# 0012|0062: YES
# 0020|000d: 1000003
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 71.5
# PSAD_REPORT: nan
# PSA_REPORT: 13
# ----------------------------------------------------------------------
# 0008|0020: 2020-10-23
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10006
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000006
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 27
# PSAD_REPORT: 0.23
# PSA_REPORT: 6.2
# ----------------------------------------------------------------------
# 0008|0020: 2012-09-21
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10017
# 0010|0040: M
# 0010|1010: 067Y
# 0012|0062: YES
# 0020|000d: 1000017
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: nan
# PSAD_REPORT: nan
# PSA_REPORT: 5.5
# ----------------------------------------------------------------------

# %%
show_metadata(grouped_files['adc'][:5])
# Out:
# 0008|0020: 2019-07-02
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10000
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000000
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 55
# PSAD_REPORT: nan
# PSA_REPORT: 7.7
# ----------------------------------------------------------------------
# 0008|0020: 2016-05-27
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10001
# 0010|0040: M
# 0010|1010: 064Y
# 0012|0062: YES
# 0020|000d: 1000001
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 102
# PSAD_REPORT: 0.09
# PSA_REPORT: 8.7
# ----------------------------------------------------------------------
# 0008|0020: 2019-04-05
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10003
# 0010|0040: M
# 0010|1010: 072Y
# 0012|0062: YES
# 0020|000d: 1000003
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 71.5
# PSAD_REPORT: nan
# PSA_REPORT: 13
# ----------------------------------------------------------------------
# 0008|0020: 2020-10-23
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10006
# 0010|0040: M
# 0010|1010: 073Y
# 0012|0062: YES
# 0020|000d: 1000006
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: 27
# PSAD_REPORT: 0.23
# PSA_REPORT: 6.2
# ----------------------------------------------------------------------
# 0008|0020: 2012-09-21
# 0008|0060: MR
# 0008|0070: SIEMENS
# 0008|1090: Skyra
# 0010|0020: 10017
# 0010|0040: M
# 0010|1010: 067Y
# 0012|0062: YES
# 0020|000d: 1000017
# ANONYMISATION_SCRIPT: PI-CAI anonymisation script v2.0
# ITK_InputFilterName: MetaImageIO
# ITK_original_direction: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# ITK_original_spacing: [UNKNOWN_PRINT_CHARACTERISTICS]
#
# Modality: MET_MOD_UNKNOWN
# PROSTATE_VOLUME_REPORT: nan
# PSAD_REPORT: nan
# PSA_REPORT: 5.5
# ----------------------------------------------------------------------

# %% [markdown]
# ## Separate DataFrame by filetype

# %%
def df_builder(g_file, column):
    df = pd.DataFrame(columns=column)
    
    d = dict()
    
    for i in g_file:
        image = sitk.ReadImage(i)
    
        keys = image.GetMetaDataKeys()
    
        for key, keyy in zip(keys, column):
            d[keyy] = image.GetMetaData(key)
    
        new_row = pd.DataFrame(d, index = [0])
        df = pd.concat([df, new_row], ignore_index=True)
    
    return df

# %%
k = ['Study Date', 'Modality', 'Manufacturer', "Manufacturer's Model Name",
     'Patient ID', "Patient's Sex", "Patient's Age", "Patient Identity Removed",
     "Study Instance UID", 'ANONYMISATION_SCRIPT', 'ITK_InputFilterName', 'ITK_original_direction',
     'ITK_original_spacing', 'Modality (Repeated)', 'PROSTATE_VOLUME_REPORT', 'PSAD_REPORT', 'PSA_REPORT']

k_hbv = ['Study_Date', 'Modality', 'Manufacturer', "Manufacturer's_Model_Name",
     'Patient_ID', "Patient's_Sex", "Patient's_Age", "Patient_Identity_Removed", "Diffusion_sensitization_factor sec/mm",
     "Study Instance_UID", 'ANONYMISATION_SCRIPT', 'ITK_InputFilterName', 'ITK_original_direction',
     'ITK_original_spacing', 'Modality_(Repeated)', 'PROSTATE_VOLUME_REPORT', 'PSAD_REPORT', 'PSA_REPORT']

df_adc = df_builder(grouped_files['adc'], column=k)
df_adc['path'] = grouped_files['adc']
df_adc
# Out:
#      Study Date Modality Manufacturer Manufacturer's Model Name Patient ID  \
# 0    2019-07-02       MR      SIEMENS                     Skyra      10000
# 1    2016-05-27       MR      SIEMENS                     Skyra      10001
# 2    2019-04-05       MR      SIEMENS                     Skyra      10003
# 3    2020-10-23       MR      SIEMENS                     Skyra      10006
# 4    2012-09-21       MR      SIEMENS                     Skyra      10017
# ..          ...      ...          ...                       ...        ...
# 295  2020-02-21       MR      SIEMENS                     Skyra      11467
# 296  2020-04-18       MR      SIEMENS                     Skyra      11469
# 297  2012-08-25       MR      SIEMENS                     Skyra      11471
# 298  2017-09-24       MR      SIEMENS                     Skyra      11473
# 299  2016-05-03       MR      SIEMENS                    Avanto      11474
#
#     Patient's Sex Patient's Age Patient Identity Removed Study Instance UID  \
# 0               M          073Y                      YES            1000000
# 1               M          064Y                      YES            1000001
# 2               M          072Y                      YES            1000003
# 3               M          073Y                      YES            1000006
# 4               M          067Y                      YES            1000017
# ..            ...           ...                      ...                ...
# 295             M          061Y                      YES            1001491
# 296             M          049Y                      YES            1001493
# 297             M          071Y                      YES            1001495
# 298             M          056Y                      YES            1001497
# 299             M          071Y                      YES            1001498
#
#                  ANONYMISATION_SCRIPT ITK_InputFilterName  \
# 0    PI-CAI anonymisation script v2.0         MetaImageIO
# 1    PI-CAI anonymisation script v2.0         MetaImageIO
# 2    PI-CAI anonymisation script v2.0         MetaImageIO
# 3    PI-CAI anonymisation script v2.0         MetaImageIO
# 4    PI-CAI anonymisation script v2.0         MetaImageIO
# ..                                ...                 ...
# 295  PI-CAI anonymisation script v2.0         MetaImageIO
# 296  PI-CAI anonymisation script v2.0         MetaImageIO
# 297  PI-CAI anonymisation script v2.0         MetaImageIO
# 298  PI-CAI anonymisation script v2.0         MetaImageIO
# 299  PI-CAI anonymisation script v2.0         MetaImageIO
#
#                 ITK_original_direction               ITK_original_spacing  \
# 0    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 1    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 2    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 3    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 4    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# ..                                 ...                                ...
# 295  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 296  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 297  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 298  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 299  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
#
#     Modality (Repeated) PROSTATE_VOLUME_REPORT PSAD_REPORT PSA_REPORT  \
# 0       MET_MOD_UNKNOWN                     55         nan        7.7
# 1       MET_MOD_UNKNOWN                    102        0.09        8.7
# 2       MET_MOD_UNKNOWN                   71.5         nan         13
# 3       MET_MOD_UNKNOWN                     27        0.23        6.2
# 4       MET_MOD_UNKNOWN                    nan         nan        5.5
# ..                  ...                    ...         ...        ...
# 295     MET_MOD_UNKNOWN                    103        0.05        5.4
# 296     MET_MOD_UNKNOWN                     34        0.13        4.3
# 297     MET_MOD_UNKNOWN                     62        0.21       12.5
# 298     MET_MOD_UNKNOWN                     87        0.34       29.6
# 299     MET_MOD_UNKNOWN                     83         nan         12
#
#                                                   path
# 0    picai_public_images_fold0/10000/10000_1000000_...
# 1    picai_public_images_fold0/10001/10001_1000001_...
# 2    picai_public_images_fold0/10003/10003_1000003_...
# 3    picai_public_images_fold0/10006/10006_1000006_...
# 4    picai_public_images_fold0/10017/10017_1000017_...
# ..                                                 ...
# 295  picai_public_images_fold0/11467/11467_1001491_...
# 296  picai_public_images_fold0/11469/11469_1001493_...
# 297  picai_public_images_fold0/11471/11471_1001495_...
# 298  picai_public_images_fold0/11473/11473_1001497_...
# 299  picai_public_images_fold0/11474/11474_1001498_...
#
# [300 rows x 18 columns]

# %%
df_cor = df_builder(grouped_files['cor'], column=k)
df_cor['path'] = grouped_files['cor']
df_cor
# Out:
#      Study Date Modality Manufacturer Manufacturer's Model Name Patient ID  \
# 0    2019-07-02       MR      SIEMENS                     Skyra      10000
# 1    2016-05-27       MR      SIEMENS                     Skyra      10001
# 2    2019-04-05       MR      SIEMENS                     Skyra      10003
# 3    2020-10-23       MR      SIEMENS                     Skyra      10006
# 4    2012-09-21       MR      SIEMENS                     Skyra      10017
# ..          ...      ...          ...                       ...        ...
# 295  2020-02-21       MR      SIEMENS                     Skyra      11467
# 296  2020-04-18       MR      SIEMENS                     Skyra      11469
# 297  2012-08-25       MR      SIEMENS                     Skyra      11471
# 298  2017-09-24       MR      SIEMENS                     Skyra      11473
# 299  2016-05-03       MR      SIEMENS                    Avanto      11474
#
#     Patient's Sex Patient's Age Patient Identity Removed Study Instance UID  \
# 0               M          073Y                      YES            1000000
# 1               M          064Y                      YES            1000001
# 2               M          072Y                      YES            1000003
# 3               M          073Y                      YES            1000006
# 4               M          067Y                      YES            1000017
# ..            ...           ...                      ...                ...
# 295             M          061Y                      YES            1001491
# 296             M          049Y                      YES            1001493
# 297             M          071Y                      YES            1001495
# 298             M          056Y                      YES            1001497
# 299             M          071Y                      YES            1001498
#
#                  ANONYMISATION_SCRIPT ITK_InputFilterName  \
# 0    PI-CAI anonymisation script v2.0         MetaImageIO
# 1    PI-CAI anonymisation script v2.0         MetaImageIO
# 2    PI-CAI anonymisation script v2.0         MetaImageIO
# 3    PI-CAI anonymisation script v2.0         MetaImageIO
# 4    PI-CAI anonymisation script v2.0         MetaImageIO
# ..                                ...                 ...
# 295  PI-CAI anonymisation script v2.0         MetaImageIO
# 296  PI-CAI anonymisation script v2.0         MetaImageIO
# 297  PI-CAI anonymisation script v2.0         MetaImageIO
# 298  PI-CAI anonymisation script v2.0         MetaImageIO
# 299  PI-CAI anonymisation script v2.0         MetaImageIO
#
#                 ITK_original_direction               ITK_original_spacing  \
# 0    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 1    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 2    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 3    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 4    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# ..                                 ...                                ...
# 295  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 296  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 297  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 298  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 299  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
#
#     Modality (Repeated) PROSTATE_VOLUME_REPORT PSAD_REPORT PSA_REPORT  \
# 0       MET_MOD_UNKNOWN                     55         nan        7.7
# 1       MET_MOD_UNKNOWN                    102        0.09        8.7
# 2       MET_MOD_UNKNOWN                   71.5         nan         13
# 3       MET_MOD_UNKNOWN                     27        0.23        6.2
# 4       MET_MOD_UNKNOWN                    nan         nan        5.5
# ..                  ...                    ...         ...        ...
# 295     MET_MOD_UNKNOWN                    103        0.05        5.4
# 296     MET_MOD_UNKNOWN                     34        0.13        4.3
# 297     MET_MOD_UNKNOWN                     62        0.21       12.5
# 298     MET_MOD_UNKNOWN                     87        0.34       29.6
# 299     MET_MOD_UNKNOWN                     83         nan         12
#
#                                                   path
# 0    picai_public_images_fold0/10000/10000_1000000_...
# 1    picai_public_images_fold0/10001/10001_1000001_...
# 2    picai_public_images_fold0/10003/10003_1000003_...
# 3    picai_public_images_fold0/10006/10006_1000006_...
# 4    picai_public_images_fold0/10017/10017_1000017_...
# ..                                                 ...
# 295  picai_public_images_fold0/11467/11467_1001491_...
# 296  picai_public_images_fold0/11469/11469_1001493_...
# 297  picai_public_images_fold0/11471/11471_1001495_...
# 298  picai_public_images_fold0/11473/11473_1001497_...
# 299  picai_public_images_fold0/11474/11474_1001498_...
#
# [300 rows x 18 columns]

# %%
df_sag = df_builder(grouped_files['sag'], column=k)
df_sag['path'] = grouped_files['sag']
df_sag
# Out:
#      Study Date Modality Manufacturer Manufacturer's Model Name Patient ID  \
# 0    2019-07-02       MR      SIEMENS                     Skyra      10000
# 1    2016-05-27       MR      SIEMENS                     Skyra      10001
# 2    2019-04-05       MR      SIEMENS                     Skyra      10003
# 3    2020-10-23       MR      SIEMENS                     Skyra      10006
# 4    2012-09-21       MR      SIEMENS                     Skyra      10017
# ..          ...      ...          ...                       ...        ...
# 295  2020-02-21       MR      SIEMENS                     Skyra      11467
# 296  2020-04-18       MR      SIEMENS                     Skyra      11469
# 297  2012-08-25       MR      SIEMENS                     Skyra      11471
# 298  2017-09-24       MR      SIEMENS                     Skyra      11473
# 299  2016-05-03       MR      SIEMENS                    Avanto      11474
#
#     Patient's Sex Patient's Age Patient Identity Removed Study Instance UID  \
# 0               M          073Y                      YES            1000000
# 1               M          064Y                      YES            1000001
# 2               M          072Y                      YES            1000003
# 3               M          073Y                      YES            1000006
# 4               M          067Y                      YES            1000017
# ..            ...           ...                      ...                ...
# 295             M          061Y                      YES            1001491
# 296             M          049Y                      YES            1001493
# 297             M          071Y                      YES            1001495
# 298             M          056Y                      YES            1001497
# 299             M          071Y                      YES            1001498
#
#                  ANONYMISATION_SCRIPT ITK_InputFilterName  \
# 0    PI-CAI anonymisation script v2.0         MetaImageIO
# 1    PI-CAI anonymisation script v2.0         MetaImageIO
# 2    PI-CAI anonymisation script v2.0         MetaImageIO
# 3    PI-CAI anonymisation script v2.0         MetaImageIO
# 4    PI-CAI anonymisation script v2.0         MetaImageIO
# ..                                ...                 ...
# 295  PI-CAI anonymisation script v2.0         MetaImageIO
# 296  PI-CAI anonymisation script v2.0         MetaImageIO
# 297  PI-CAI anonymisation script v2.0         MetaImageIO
# 298  PI-CAI anonymisation script v2.0         MetaImageIO
# 299  PI-CAI anonymisation script v2.0         MetaImageIO
#
#                 ITK_original_direction               ITK_original_spacing  \
# 0    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 1    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 2    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 3    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 4    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# ..                                 ...                                ...
# 295  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 296  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 297  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 298  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 299  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
#
#     Modality (Repeated) PROSTATE_VOLUME_REPORT PSAD_REPORT PSA_REPORT  \
# 0       MET_MOD_UNKNOWN                     55         nan        7.7
# 1       MET_MOD_UNKNOWN                    102        0.09        8.7
# 2       MET_MOD_UNKNOWN                   71.5         nan         13
# 3       MET_MOD_UNKNOWN                     27        0.23        6.2
# 4       MET_MOD_UNKNOWN                    nan         nan        5.5
# ..                  ...                    ...         ...        ...
# 295     MET_MOD_UNKNOWN                    103        0.05        5.4
# 296     MET_MOD_UNKNOWN                     34        0.13        4.3
# 297     MET_MOD_UNKNOWN                     62        0.21       12.5
# 298     MET_MOD_UNKNOWN                     87        0.34       29.6
# 299     MET_MOD_UNKNOWN                     83         nan         12
#
#                                                   path
# 0    picai_public_images_fold0/10000/10000_1000000_...
# 1    picai_public_images_fold0/10001/10001_1000001_...
# 2    picai_public_images_fold0/10003/10003_1000003_...
# 3    picai_public_images_fold0/10006/10006_1000006_...
# 4    picai_public_images_fold0/10017/10017_1000017_...
# ..                                                 ...
# 295  picai_public_images_fold0/11467/11467_1001491_...
# 296  picai_public_images_fold0/11469/11469_1001493_...
# 297  picai_public_images_fold0/11471/11471_1001495_...
# 298  picai_public_images_fold0/11473/11473_1001497_...
# 299  picai_public_images_fold0/11474/11474_1001498_...
#
# [300 rows x 18 columns]

# %%
df_t2w = df_builder(grouped_files['t2w'], column=k)
df_t2w['path'] = grouped_files['t2w']
df_t2w
# Out:
#      Study Date Modality Manufacturer Manufacturer's Model Name Patient ID  \
# 0    2019-07-02       MR      SIEMENS                     Skyra      10000
# 1    2016-05-27       MR      SIEMENS                     Skyra      10001
# 2    2019-04-05       MR      SIEMENS                     Skyra      10003
# 3    2020-10-23       MR      SIEMENS                     Skyra      10006
# 4    2012-09-21       MR      SIEMENS                     Skyra      10017
# ..          ...      ...          ...                       ...        ...
# 295  2020-02-21       MR      SIEMENS                     Skyra      11467
# 296  2020-04-18       MR      SIEMENS                     Skyra      11469
# 297  2012-08-25       MR      SIEMENS                     Skyra      11471
# 298  2017-09-24       MR      SIEMENS                     Skyra      11473
# 299  2016-05-03       MR      SIEMENS                    Avanto      11474
#
#     Patient's Sex Patient's Age Patient Identity Removed Study Instance UID  \
# 0               M          073Y                      YES            1000000
# 1               M          064Y                      YES            1000001
# 2               M          072Y                      YES            1000003
# 3               M          073Y                      YES            1000006
# 4               M          067Y                      YES            1000017
# ..            ...           ...                      ...                ...
# 295             M          061Y                      YES            1001491
# 296             M          049Y                      YES            1001493
# 297             M          071Y                      YES            1001495
# 298             M          056Y                      YES            1001497
# 299             M          071Y                      YES            1001498
#
#                  ANONYMISATION_SCRIPT ITK_InputFilterName  \
# 0    PI-CAI anonymisation script v2.0         MetaImageIO
# 1    PI-CAI anonymisation script v2.0         MetaImageIO
# 2    PI-CAI anonymisation script v2.0         MetaImageIO
# 3    PI-CAI anonymisation script v2.0         MetaImageIO
# 4    PI-CAI anonymisation script v2.0         MetaImageIO
# ..                                ...                 ...
# 295  PI-CAI anonymisation script v2.0         MetaImageIO
# 296  PI-CAI anonymisation script v2.0         MetaImageIO
# 297  PI-CAI anonymisation script v2.0         MetaImageIO
# 298  PI-CAI anonymisation script v2.0         MetaImageIO
# 299  PI-CAI anonymisation script v2.0         MetaImageIO
#
#                 ITK_original_direction               ITK_original_spacing  \
# 0    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 1    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 2    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 3    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 4    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# ..                                 ...                                ...
# 295  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 296  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 297  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 298  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 299  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
#
#     Modality (Repeated) PROSTATE_VOLUME_REPORT PSAD_REPORT PSA_REPORT  \
# 0       MET_MOD_UNKNOWN                     55         nan        7.7
# 1       MET_MOD_UNKNOWN                    102        0.09        8.7
# 2       MET_MOD_UNKNOWN                   71.5         nan         13
# 3       MET_MOD_UNKNOWN                     27        0.23        6.2
# 4       MET_MOD_UNKNOWN                    nan         nan        5.5
# ..                  ...                    ...         ...        ...
# 295     MET_MOD_UNKNOWN                    103        0.05        5.4
# 296     MET_MOD_UNKNOWN                     34        0.13        4.3
# 297     MET_MOD_UNKNOWN                     62        0.21       12.5
# 298     MET_MOD_UNKNOWN                     87        0.34       29.6
# 299     MET_MOD_UNKNOWN                     83         nan         12
#
#                                                   path
# 0    picai_public_images_fold0/10000/10000_1000000_...
# 1    picai_public_images_fold0/10001/10001_1000001_...
# 2    picai_public_images_fold0/10003/10003_1000003_...
# 3    picai_public_images_fold0/10006/10006_1000006_...
# 4    picai_public_images_fold0/10017/10017_1000017_...
# ..                                                 ...
# 295  picai_public_images_fold0/11467/11467_1001491_...
# 296  picai_public_images_fold0/11469/11469_1001493_...
# 297  picai_public_images_fold0/11471/11471_1001495_...
# 298  picai_public_images_fold0/11473/11473_1001497_...
# 299  picai_public_images_fold0/11474/11474_1001498_...
#
# [300 rows x 18 columns]

# %%
df_hbv = df_builder(grouped_files['hbv'], column=k_hbv)
df_hbv['path'] = grouped_files['hbv']
df_hbv
# Out:
#      Study_Date Modality Manufacturer Manufacturer's_Model_Name Patient_ID  \
# 0    2019-07-02       MR      SIEMENS                     Skyra      10000
# 1    2016-05-27       MR      SIEMENS                     Skyra      10001
# 2    2019-04-05       MR      SIEMENS                     Skyra      10003
# 3    2020-10-23       MR      SIEMENS                     Skyra      10006
# 4    2012-09-21       MR      SIEMENS                     Skyra      10017
# ..          ...      ...          ...                       ...        ...
# 295  2020-02-21       MR      SIEMENS                     Skyra      11467
# 296  2020-04-18       MR      SIEMENS                     Skyra      11469
# 297  2012-08-25       MR      SIEMENS                     Skyra      11471
# 298  2017-09-24       MR      SIEMENS                     Skyra      11473
# 299  2016-05-03       MR      SIEMENS                    Avanto      11474
#
#     Patient's_Sex Patient's_Age Patient_Identity_Removed  \
# 0               M          073Y                      YES
# 1               M          064Y                      YES
# 2               M          072Y                      YES
# 3               M          073Y                      YES
# 4               M          067Y                      YES
# ..            ...           ...                      ...
# 295             M          061Y                      YES
# 296             M          049Y                      YES
# 297             M          071Y                      YES
# 298             M          056Y                      YES
# 299             M          071Y                      YES
#
#     Diffusion_sensitization_factor sec/mm Study Instance_UID  \
# 0                                    1400            1000000
# 1                                    1400            1000001
# 2                                    1400            1000003
# 3                                    1400            1000006
# 4                                    1400            1000017
# ..                                    ...                ...
# 295                                  1400            1001491
# 296                                  1400            1001493
# 297                                  1400            1001495
# 298                                  1400            1001497
# 299                                  1500            1001498
#
#                  ANONYMISATION_SCRIPT ITK_InputFilterName  \
# 0    PI-CAI anonymisation script v2.0         MetaImageIO
# 1    PI-CAI anonymisation script v2.0         MetaImageIO
# 2    PI-CAI anonymisation script v2.0         MetaImageIO
# 3    PI-CAI anonymisation script v2.0         MetaImageIO
# 4    PI-CAI anonymisation script v2.0         MetaImageIO
# ..                                ...                 ...
# 295  PI-CAI anonymisation script v2.0         MetaImageIO
# 296  PI-CAI anonymisation script v2.0         MetaImageIO
# 297  PI-CAI anonymisation script v2.0         MetaImageIO
# 298  PI-CAI anonymisation script v2.0         MetaImageIO
# 299  PI-CAI anonymisation script v2.0         MetaImageIO
#
#                 ITK_original_direction               ITK_original_spacing  \
# 0    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 1    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 2    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 3    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 4    [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# ..                                 ...                                ...
# 295  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 296  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 297  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 298  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
# 299  [UNKNOWN_PRINT_CHARACTERISTICS]\n  [UNKNOWN_PRINT_CHARACTERISTICS]\n
#
#     Modality_(Repeated) PROSTATE_VOLUME_REPORT PSAD_REPORT PSA_REPORT  \
# 0       MET_MOD_UNKNOWN                     55         nan        7.7
# 1       MET_MOD_UNKNOWN                    102        0.09        8.7
# 2       MET_MOD_UNKNOWN                   71.5         nan         13
# 3       MET_MOD_UNKNOWN                     27        0.23        6.2
# 4       MET_MOD_UNKNOWN                    nan         nan        5.5
# ..                  ...                    ...         ...        ...
# 295     MET_MOD_UNKNOWN                    103        0.05        5.4
# 296     MET_MOD_UNKNOWN                     34        0.13        4.3
# 297     MET_MOD_UNKNOWN                     62        0.21       12.5
# 298     MET_MOD_UNKNOWN                     87        0.34       29.6
# 299     MET_MOD_UNKNOWN                     83         nan         12
#
#                                                   path
# 0    picai_public_images_fold0/10000/10000_1000000_...
# 1    picai_public_images_fold0/10001/10001_1000001_...
# 2    picai_public_images_fold0/10003/10003_1000003_...
# 3    picai_public_images_fold0/10006/10006_1000006_...
# 4    picai_public_images_fold0/10017/10017_1000017_...
# ..                                                 ...
# 295  picai_public_images_fold0/11467/11467_1001491_...
# 296  picai_public_images_fold0/11469/11469_1001493_...
# 297  picai_public_images_fold0/11471/11471_1001495_...
# 298  picai_public_images_fold0/11473/11473_1001497_...
# 299  picai_public_images_fold0/11474/11474_1001498_...
#
# [300 rows x 19 columns]

# %% [markdown]
# ## EDA of Dateframes

# %%
print(df_adc.duplicated(k).sum())
print(df_cor.duplicated(k).sum())
print(df_hbv.duplicated(k_hbv).sum())
print(df_sag.duplicated(k).sum())
print(df_t2w.duplicated(k).sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
df_adc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Study Date                 300 non-null    object
#  1   Modality                   300 non-null    object
#  2   Manufacturer               300 non-null    object
#  3   Manufacturer's Model Name  300 non-null    object
#  4   Patient ID                 300 non-null    object
#  5   Patient's Sex              300 non-null    object
#  6   Patient's Age              300 non-null    object
#  7   Patient Identity Removed   300 non-null    object
#  8   Study Instance UID         300 non-null    object
#  9   ANONYMISATION_SCRIPT       300 non-null    object
#  10  ITK_InputFilterName        300 non-null    object
#  11  ITK_original_direction     300 non-null    object
#  12  ITK_original_spacing       300 non-null    object
#  13  Modality (Repeated)        300 non-null    object
#  14  PROSTATE_VOLUME_REPORT     300 non-null    object
#  15  PSAD_REPORT                300 non-null    object
#  16  PSA_REPORT                 300 non-null    object
#  17  path                       300 non-null    object
# dtypes: object(18)
# memory usage: 42.3+ KB

# %%
df_adc['Study Date'] = pd.to_datetime(df_adc['Study Date'])
df_cor['Study Date'] = pd.to_datetime(df_cor['Study Date'])
df_sag['Study Date'] = pd.to_datetime(df_sag['Study Date'])
df_t2w['Study Date'] = pd.to_datetime(df_t2w['Study Date'])
df_hbv['Study_Date'] = pd.to_datetime(df_hbv['Study_Date'])

# %%
def patient_age(df, column):
    patient_age = [int(item[:-1]) for item in list(df[column])]
    df[column] = patient_age
    return df

# %%
patient_age(df_adc, 'Patient\'s Age')
patient_age(df_cor, 'Patient\'s Age')
patient_age(df_sag, 'Patient\'s Age')
patient_age(df_t2w, 'Patient\'s Age')
patient_age(df_hbv, "Patient's_Age" )
print('done')
# Out:
# done

# %%
def df_value_counts(df, columns):
    for column in columns:
        print(df[column].value_counts())
        print("-" * 70)

# %%
df_value_counts(df_adc, k)
# Out:
# Study Date
# 2019-01-16    2
# 2012-08-25    2
# 2019-02-23    2
# 2018-04-23    2
# 2012-08-23    2
#              ..
# 2015-12-11    1
# 2018-11-22    1
# 2018-11-12    1
# 2015-06-13    1
# 2016-05-03    1
# Name: count, Length: 288, dtype: int64
# ----------------------------------------------------------------------
# Modality
# MR    300
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# Manufacturer
# SIEMENS                    242
# Philips Medical Systems     58
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# Manufacturer's Model Name
# Skyra         205
# Ingenia        47
# TrioTim        17
# Prisma_fit     13
# Achieva        11
# Aera            4
# Prisma          2
# Avanto          1
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# Patient ID
# 10129    2
# 10193    2
# 11383    2
# 11087    2
# 10540    2
#         ..
# 10526    1
# 10525    1
# 10524    1
# 10522    1
# 11474    1
# Name: count, Length: 295, dtype: int64
# ----------------------------------------------------------------------
# Patient's Sex
# M    300
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# Patient's Age
# 66    20
# 71    20
# 69    18
# 62    17
# 65    16
# 67    16
# 70    15
# 68    14
# 73    14
# 63    14
# 61    12
# 64    12
# 60    12
# 58    11
# 56    10
# 72     8
# 59     8
# 75     8
# 74     7
# 77     7
# 78     6
# 76     5
# 54     5
# 55     4
# 51     3
# 57     3
# 50     3
# 49     3
# 43     2
# 81     2
# 48     1
# 79     1
# 52     1
# 89     1
# 45     1
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# Patient Identity Removed
# YES    300
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# Study Instance UID
# 0          58
# 1000000     1
# 1001055     1
# 1000997     1
# 1001001     1
#            ..
# 1000574     1
# 1000577     1
# 1000580     1
# 1000583     1
# 1001498     1
# Name: count, Length: 243, dtype: int64
# ----------------------------------------------------------------------
# ANONYMISATION_SCRIPT
# PI-CAI anonymisation script v2.0    242
# 1001026                               1
# 1000759                               1
# 1000823                               1
# 1000829                               1
# 1000857                               1
# 1000863                               1
# 1000918                               1
# 1000930                               1
# 1000938                               1
# 1000948                               1
# 1000952                               1
# 1000974                               1
# 1001000                               1
# 1001160                               1
# 1000690                               1
# 1001189                               1
# 1001199                               1
# 1001200                               1
# 1001211                               1
# 1001257                               1
# 1001283                               1
# 1001311                               1
# 1001327                               1
# 1001374                               1
# 1001400                               1
# 1001416                               1
# 1001466                               1
# 1000696                               1
# 1000663                               1
# 1000022                               1
# 1000369                               1
# 1000035                               1
# 1000041                               1
# 1000065                               1
# 1000085                               1
# 1000144                               1
# 1000176                               1
# 1000261                               1
# 1000267                               1
# 1000307                               1
# 1000321                               1
# 1000342                               1
# 1000344                               1
# 1000398                               1
# 1000655                               1
# 1000445                               1
# 1000532                               1
# 1000534                               1
# 1000536                               1
# 1000538                               1
# 1000550                               1
# 1000551                               1
# 1000552                               1
# 1000553                               1
# 1000584                               1
# 1000595                               1
# 1000629                               1
# 1001485                               1
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# ITK_InputFilterName
# MetaImageIO                         242
# PI-CAI anonymisation script v2.0     58
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# ITK_original_direction
# [UNKNOWN_PRINT_CHARACTERISTICS]\n    242
# MetaImageIO                           58
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# ITK_original_spacing
# [UNKNOWN_PRINT_CHARACTERISTICS]\n    300
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# Modality (Repeated)
# MET_MOD_UNKNOWN                      242
# [UNKNOWN_PRINT_CHARACTERISTICS]\n     58
# Name: count, dtype: int64
# ----------------------------------------------------------------------
# PROSTATE_VOLUME_REPORT
# MET_MOD_UNKNOWN    58
# 55                  5
# 44                  5
# 35                  5
# 38                  5
#                    ..
# 54                  1
# 22                  1
# 48.92               1
# 85                  1
# 115                 1
# Name: count, Length: 121, dtype: int64
# ----------------------------------------------------------------------
# PSAD_REPORT
# nan      36
# 0.08     12
# 0.2      11
# 0.1      11
# 0.09     10
#          ..
# 0.8       1
# 0.589     1
# 0.31      1
# 0.57      1
# 1.3       1
# Name: count, Length: 104, dtype: int64
# ----------------------------------------------------------------------
# PSA_REPORT
# nan     64
# 12       7
# 7        7
# 11       7
# 7.7      5
#         ..
# 15.8     1
# 8.19     1
# 2.9      1
# 21.7     1
# 29.6     1
# Name: count, Length: 138, dtype: int64
# ----------------------------------------------------------------------

# %%
df_adc = df_adc.replace('nan', np.nan)
df_cor = df_cor.replace('nan', np.nan)
df_hbv = df_hbv.replace('nan', np.nan)
df_sag = df_sag.replace('nan', np.nan)
df_t2w = df_t2w.replace('nan', np.nan)

df_adc = df_adc.replace('MET_MOD_UNKNOWN', np.nan)
df_cor = df_cor.replace('MET_MOD_UNKNOWN', np.nan)
df_hbv = df_hbv.replace('MET_MOD_UNKNOWN', np.nan)
df_sag = df_sag.replace('MET_MOD_UNKNOWN', np.nan)
df_t2w = df_t2w.replace('MET_MOD_UNKNOWN', np.nan)
# Out:
# /tmp/ipykernel_145573/1849344122.py:9: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_hbv = df_hbv.replace('MET_MOD_UNKNOWN', np.nan)

# %%
df_adc[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']] = df_adc[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']].astype('float64')
df_cor[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']] = df_cor[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']].astype('float64')
df_sag[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']] = df_sag[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']].astype('float64')
df_t2w[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']] = df_t2w[['PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']].astype('float64')
df_hbv[['Diffusion_sensitization_factor sec/mm', 'PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']] = df_hbv[['Diffusion_sensitization_factor sec/mm', 
                                                                                         'PSA_REPORT', 'PSAD_REPORT', 'PROSTATE_VOLUME_REPORT']].astype('float64')

# %%
df_hbv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 19 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Study_Date                             300 non-null    datetime64[ns]
#  1   Modality                               300 non-null    object
#  2   Manufacturer                           300 non-null    object
#  3   Manufacturer's_Model_Name              300 non-null    object
#  4   Patient_ID                             300 non-null    object
#  5   Patient's_Sex                          300 non-null    object
#  6   Patient's_Age                          300 non-null    int64
#  7   Patient_Identity_Removed               300 non-null    object
#  8   Diffusion_sensitization_factor sec/mm  300 non-null    float64
#  9   Study Instance_UID                     300 non-null    object
#  10  ANONYMISATION_SCRIPT                   300 non-null    object
#  11  ITK_InputFilterName                    300 non-null    object
#  12  ITK_original_direction                 300 non-null    object
#  13  ITK_original_spacing                   300 non-null    object
#  14  Modality_(Repeated)                    0 non-null      float64
#  15  PROSTATE_VOLUME_REPORT                 296 non-null    float64
#  16  PSAD_REPORT                            207 non-null    float64
#  17  PSA_REPORT                             293 non-null    float64
#  18  path                                   300 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(12)
# memory usage: 44.7+ KB

# %% [markdown]
# ## EDA of Pictures

# %%
for i, pic in enumerate(grouped_files['adc'][:5]):
    image = sitk.ReadImage(pic)
    print(f"picture: {i}")
    print(f"Dimention: {image.GetDimension()}")
    print(f"Spacing: {image.GetSpacing()}")
    print(f"Depth: {image.GetDepth()}")
    print(f"Direction: {image.GetDirection()}")
    print(f"Shape: {image.GetSize()}")
    print("-" * 70)
# Out:
# picture: 0
# Dimention: 3
# Spacing: (1.75438594818, 1.75438594818, 3.2999999825580133)
# Depth: 31
# Direction: (1.0, 0.0, 0.0, 0.0, 0.9198214958019287, 0.39233712016670375, 0.0, -0.39233712016670375, 0.9198214958019287)
# Shape: (116, 114, 31)
# ----------------------------------------------------------------------
# picture: 1
# Dimention: 3
# Spacing: (2.0, 2.0, 3.6000000778885344)
# Depth: 21
# Direction: (0.9996148108062515, -1.6670999975453016e-11, -0.02775301815627119, 0.00043710598429775216, 0.999875963366245, 0.01574378673580096, 0.027749575765060076, -0.015749853409600077, 0.9994908219500744)
# Shape: (120, 128, 21)
# ----------------------------------------------------------------------
# picture: 2
# Dimention: 3
# Spacing: (2.0, 2.0, 3.0000000803421303)
# Depth: 23
# Direction: (1.0, -4.896999999999999e-12, 5.819077202182931e-17, 4.755630674582797e-12, 0.9711342771144598, 0.23853346895849994, -1.1681549085430961e-12, -0.23853346895849994, 0.9711342771144598)
# Shape: (120, 128, 23)
# ----------------------------------------------------------------------
# picture: 3
# Dimention: 3
# Spacing: (2.0, 2.0, 2.9999999763973566)
# Depth: 21
# Direction: (1.0, -4.8970000000001024e-12, -2.8163893284788817e-16, 4.262270524388219e-12, 0.8703556950667182, 0.4924235616468103, -2.4111530553353235e-12, -0.4924235616468103, 0.8703556950667182)
# Shape: (120, 128, 21)
# ----------------------------------------------------------------------
# picture: 4
# Dimention: 3
# Spacing: (2.0, 2.0, 2.999999977095152)
# Depth: 19
# Direction: (1.0, 2.051034000000021e-10, 3.80076597661075e-17, -1.939290882094323e-10, 0.9455185815317899, 0.3255681372280034, 6.677509594018221e-11, -0.3255681372280034, 0.9455185815317899)
# Shape: (84, 128, 19)
# ----------------------------------------------------------------------

# %%
def show_image(path):
    image = sitk.ReadImage(path)

    image_array = sitk.GetArrayFromImage(image)
    
    plt.figure(figsize=(15, 15))
    for i in range(image.GetDepth()):
        plt.subplot(4, 8, i+1)
        plt.imshow(image_array[i], cmap='gray')
        plt.title(f"Slice {i}")
    plt.tight_layout()
    plt.show()

# %%
show_image(grouped_files['adc'][0])

# %%
show_image(grouped_files['cor'][0])

# %%
show_image(grouped_files['sag'][0])

# %%
show_image(grouped_files['hbv'][0])

# %%
show_image(grouped_files['t2w'][0])

# %% [markdown]
# ## Data Cleaning (MetaData & Pictures)

# %%
df_adc = df_adc.drop(['ITK_InputFilterName', 'ITK_original_direction', 'ITK_original_spacing', 'Modality (Repeated)',
              'ANONYMISATION_SCRIPT', 'Patient Identity Removed', 'Patient\'s Sex',
              'Patient ID', 'Modality', 'Study Date'], axis = 1)

df_cor = df_cor.drop(['ITK_InputFilterName', 'ITK_original_direction', 'ITK_original_spacing', 'Modality (Repeated)',
              'ANONYMISATION_SCRIPT', 'Patient Identity Removed', 'Patient\'s Sex',
              'Patient ID', 'Modality', 'Study Date'], axis = 1)

df_sag = df_sag.drop(['ITK_InputFilterName', 'ITK_original_direction', 'ITK_original_spacing', 'Modality (Repeated)',
              'ANONYMISATION_SCRIPT', 'Patient Identity Removed', 'Patient\'s Sex',
              'Patient ID', 'Modality', 'Study Date'], axis = 1)

df_t2w = df_t2w.drop(['ITK_InputFilterName', 'ITK_original_direction', 'ITK_original_spacing', 'Modality (Repeated)',
              'ANONYMISATION_SCRIPT', 'Patient Identity Removed', 'Patient\'s Sex',
              'Patient ID', 'Modality', 'Study Date'], axis = 1)

df_hbv = df_hbv.drop(['ITK_InputFilterName', 'ITK_original_direction', 'ITK_original_spacing', 'Modality_(Repeated)',
              'ANONYMISATION_SCRIPT', 'Patient_Identity_Removed', 'Patient\'s_Sex',
              'Patient_ID', 'Modality', 'Study_Date'], axis = 1)

# %%
df_adc.set_index('Study Instance UID', inplace=True)
df_cor.set_index('Study Instance UID', inplace=True)
df_sag.set_index('Study Instance UID', inplace=True)
df_t2w.set_index('Study Instance UID', inplace=True)
df_hbv.set_index('Study Instance_UID', inplace=True)

# %%
df_hbv['path'].duplicated().any()
# Out:
# False

# %%
df_hbv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 1000000 to 1001498
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Manufacturer                           300 non-null    object
#  1   Manufacturer's_Model_Name              300 non-null    object
#  2   Patient's_Age                          300 non-null    int64
#  3   Diffusion_sensitization_factor sec/mm  300 non-null    float64
#  4   PROSTATE_VOLUME_REPORT                 296 non-null    object
#  5   PSAD_REPORT                            207 non-null    float64
#  6   PSA_REPORT                             293 non-null    float64
#  7   path                                   300 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 21.1+ KB

# %%
df_adc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 1000000 to 1001498
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Manufacturer               300 non-null    object
#  1   Manufacturer's Model Name  300 non-null    object
#  2   Patient's Age              300 non-null    int64
#  3   PROSTATE_VOLUME_REPORT     239 non-null    object
#  4   PSAD_REPORT                264 non-null    float64
#  5   PSA_REPORT                 236 non-null    float64
#  6   path                       300 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 18.8+ KB

# %%
df_cor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 1000000 to 1001498
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Manufacturer               300 non-null    object
#  1   Manufacturer's Model Name  300 non-null    object
#  2   Patient's Age              300 non-null    int64
#  3   PROSTATE_VOLUME_REPORT     239 non-null    object
#  4   PSAD_REPORT                264 non-null    float64
#  5   PSA_REPORT                 236 non-null    float64
#  6   path                       300 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 18.8+ KB

# %%
df_sag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 1000000 to 1001498
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Manufacturer               300 non-null    object
#  1   Manufacturer's Model Name  300 non-null    object
#  2   Patient's Age              300 non-null    int64
#  3   PROSTATE_VOLUME_REPORT     239 non-null    object
#  4   PSAD_REPORT                264 non-null    float64
#  5   PSA_REPORT                 236 non-null    float64
#  6   path                       300 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 18.8+ KB

# %%
df_t2w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 1000000 to 1001498
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Manufacturer               300 non-null    object
#  1   Manufacturer's Model Name  300 non-null    object
#  2   Patient's Age              300 non-null    int64
#  3   PROSTATE_VOLUME_REPORT     239 non-null    object
#  4   PSAD_REPORT                264 non-null    float64
#  5   PSA_REPORT                 236 non-null    float64
#  6   path                       300 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 18.8+ KB

# %%
df_adc.isnull().sum()
# Out:
# Manufacturer                  0
# Manufacturer's Model Name     0
# Patient's Age                 0
# PROSTATE_VOLUME_REPORT       61
# PSAD_REPORT                  36
# PSA_REPORT                   64
# path                          0
# dtype: int64

# %%
df_adc.isnull().sum()
# Out:
# Manufacturer                  0
# Manufacturer's Model Name     0
# Patient's Age                 0
# PROSTATE_VOLUME_REPORT       61
# PSAD_REPORT                  36
# PSA_REPORT                   64
# path                          0
# dtype: int64

# %%
df_adc.describe()
# Out:
#        Patient's Age  PSAD_REPORT  PSA_REPORT
# count     300.000000   264.000000  236.000000
# mean       65.656667    12.487635   12.571992
# std         7.184533    29.842877   14.354915
# min        43.000000     0.010000    0.100000
# 25%        61.000000     0.120000    5.595000
# 50%        66.000000     0.200000    8.850000
# 75%        71.000000     0.675000   14.000000
# max        89.000000   200.000000  134.000000

# %%
df_cor.isna().sum()
# Out:
# Manufacturer                  0
# Manufacturer's Model Name     0
# Patient's Age                 0
# PROSTATE_VOLUME_REPORT       61
# PSAD_REPORT                  36
# PSA_REPORT                   64
# path                          0
# dtype: int64

# %%
df_t2w.isna().sum()
# Out:
# Manufacturer                  0
# Manufacturer's Model Name     0
# Patient's Age                 0
# PROSTATE_VOLUME_REPORT       61
# PSAD_REPORT                  36
# PSA_REPORT                   64
# path                          0
# dtype: int64

# %%
df_hbv.isna().sum()
# Out:
# Manufacturer                              0
# Manufacturer's_Model_Name                 0
# Patient's_Age                             0
# Diffusion_sensitization_factor sec/mm     0
# PROSTATE_VOLUME_REPORT                    4
# PSAD_REPORT                              93
# PSA_REPORT                                7
# path                                      0
# dtype: int64

# %%
df_sag.isna().sum()
# Out:
# Manufacturer                  0
# Manufacturer's Model Name     0
# Patient's Age                 0
# PROSTATE_VOLUME_REPORT       61
# PSAD_REPORT                  36
# PSA_REPORT                   64
# path                          0
# dtype: int64

# %%
df_hbv = df_hbv.dropna(axis=0)
df_sag = df_sag.dropna(axis=0)
df_adc = df_adc.dropna(axis=0)
df_cor = df_cor.dropna(axis=0)
df_t2w = df_t2w.dropna(axis=0)

# %%
print(df_hbv.shape)
print(df_sag.shape)
print(df_adc.shape)
print(df_cor.shape)
print(df_t2w.shape)
# Out:
# (205, 8)
# (205, 7)
# (205, 7)
# (205, 7)
# (205, 7)

# %%
df_adc.shape
# Out:
# (205, 7)

# %%
print(df_adc.isnull().sum())
print("-"*70)
print(df_hbv.isnull().sum())
print("-"*70)
print(df_sag.isnull().sum())
print("-"*70)
print(df_cor.isnull().sum())
print("-"*70)
print(df_t2w.isnull().sum())
print("-"*70)
# Out:
# Manufacturer                 0
# Manufacturer's Model Name    0
# Patient's Age                0
# PROSTATE_VOLUME_REPORT       0
# PSAD_REPORT                  0
# PSA_REPORT                   0
# path                         0
# dtype: int64
# ----------------------------------------------------------------------
# Manufacturer                             0
# Manufacturer's_Model_Name                0
# Patient's_Age                            0
# Diffusion_sensitization_factor sec/mm    0
# PROSTATE_VOLUME_REPORT                   0
# PSAD_REPORT                              0
# PSA_REPORT                               0
# path                                     0
# dtype: int64
# ----------------------------------------------------------------------
# Manufacturer                 0
# Manufacturer's Model Name    0
# Patient's Age                0
# PROSTATE_VOLUME_REPORT       0
# PSAD_REPORT                  0
# PSA_REPORT                   0
# path                         0
# dtype: int64
# ----------------------------------------------------------------------
# Manufacturer                 0
# Manufacturer's Model Name    0
# Patient's Age                0
# PROSTATE_VOLUME_REPORT       0
# PSAD_REPORT                  0
# PSA_REPORT                   0
# path                         0
# dtype: int64
# ----------------------------------------------------------------------
# Manufacturer                 0
# Manufacturer's Model Name    0
# Patient's Age                0
# PROSTATE_VOLUME_REPORT       0
# PSAD_REPORT                  0
# PSA_REPORT                   0
# path                         0
# dtype: int64
# ----------------------------------------------------------------------

# %%
df_adc.compare(df_cor)
# Out:
#                                                                  path  \
#                                                                  self
# Study Instance UID
# 1000001             picai_public_images_fold0/10001/10001_1000001_...
# 1000006             picai_public_images_fold0/10006/10006_1000006_...
# 1000020             picai_public_images_fold0/10020/10020_1000020_...
# 1000023             picai_public_images_fold0/10023/10023_1000023_...
# 1000029             picai_public_images_fold0/10029/10029_1000029_...
# ...                                                               ...
# 1001475             picai_public_images_fold0/11451/11451_1001475_...
# 1001491             picai_public_images_fold0/11467/11467_1001491_...
# 1001493             picai_public_images_fold0/11469/11469_1001493_...
# 1001495             picai_public_images_fold0/11471/11471_1001495_...
# 1001497             picai_public_images_fold0/11473/11473_1001497_...
#
#
#                                                                 other
# Study Instance UID
# 1000001             picai_public_images_fold0/10001/10001_1000001_...
# 1000006             picai_public_images_fold0/10006/10006_1000006_...
# 1000020             picai_public_images_fold0/10020/10020_1000020_...
# 1000023             picai_public_images_fold0/10023/10023_1000023_...
# 1000029             picai_public_images_fold0/10029/10029_1000029_...
# ...                                                               ...
# 1001475             picai_public_images_fold0/11451/11451_1001475_...
# 1001491             picai_public_images_fold0/11467/11467_1001491_...
# 1001493             picai_public_images_fold0/11469/11469_1001493_...
# 1001495             picai_public_images_fold0/11471/11471_1001495_...
# 1001497             picai_public_images_fold0/11473/11473_1001497_...
#
# [205 rows x 2 columns]

# %%
print(df_hbv.index.equals(df_adc.index))
print(df_adc.index.equals(df_t2w.index))
print(df_t2w.index.equals(df_cor.index))
print(df_cor.index.equals(df_sag.index))
print(df_sag.index.equals(df_hbv.index))
# Out:
# True
# True
# True
# True
# True

# %%
df_hbv['path'].duplicated().any()
# Out:
# False

# %%
paths = list(df_hbv['path']) + list(df_adc['path']) + list(df_cor['path']) + list(df_sag['path']) + list(df_t2w['path'])

destination = 'Dataset_v1'
os.makedirs(destination, exist_ok=True)

for path in paths:
    shutil.copy(path, destination)

# %%
files_v1 = os.listdir(path='Dataset_v1/')
len(files_v1)
# Out:
# 1025

# %%
name_list = []
for i in sorted(files_v1):
    name_list.append(f'Dataset_v1/{i}')
len(name_list)
# Out:
# 1025

# %%
grouped_files = defaultdict(list)

for path in name_list:
    suffix = path.split('_')[-1].split('.')[0]
    grouped_files[suffix].append(path)

grouped_files = dict(grouped_files)
grouped_files
# Out:
# {'adc': ['Dataset_v1/10001_1000001_adc.mha',
#   'Dataset_v1/10006_1000006_adc.mha',
#   'Dataset_v1/10020_1000020_adc.mha',
#   'Dataset_v1/10023_1000023_adc.mha',
#   'Dataset_v1/10029_1000029_adc.mha',
#   'Dataset_v1/10032_1000032_adc.mha',
#   'Dataset_v1/10033_1000033_adc.mha',
#   'Dataset_v1/10038_1000038_adc.mha',
#   'Dataset_v1/10040_1000040_adc.mha',
#   'Dataset_v1/10059_1000059_adc.mha',
#   'Dataset_v1/10062_1000062_adc.mha',
#   'Dataset_v1/10071_1000071_adc.mha',
#   'Dataset_v1/10073_1000073_adc.mha',
#   'Dataset_v1/10078_1000078_adc.mha',
#   'Dataset_v1/10092_1000092_adc.mha',
#   'Dataset_v1/10129_1000129_adc.mha',
#   'Dataset_v1/10136_1000138_adc.mha',
#   'Dataset_v1/10146_1000148_adc.mha',
#   'Dataset_v1/10156_1000159_adc.mha',
#   'Dataset_v1/10158_1000161_adc.mha',
#   'Dataset_v1/10165_1000168_adc.mha',
#   'Dataset_v1/10167_1000170_adc.mha',
#   'Dataset_v1/10177_1000180_adc.mha',
#   'Dataset_v1/10189_1000192_adc.mha',
#   'Dataset_v1/10193_1000196_adc.mha',
#   'Dataset_v1/10195_1000199_adc.mha',
#   'Dataset_v1/10196_1000200_adc.mha',
#   'Dataset_v1/10197_1000201_adc.mha',
#   'Dataset_v1/10198_1000202_adc.mha',
#   'Dataset_v1/10229_1000233_adc.mha',
#   'Dataset_v1/10282_1000288_adc.mha',
#   'Dataset_v1/10298_1000304_adc.mha',
#   'Dataset_v1/10302_1000308_adc.mha',
#   'Dataset_v1/10310_1000316_adc.mha',
#   'Dataset_v1/10323_1000329_adc.mha',
#   'Dataset_v1/10326_1000332_adc.mha',
#   'Dataset_v1/10345_1000351_adc.mha',
#   'Dataset_v1/10352_1000358_adc.mha',
#   'Dataset_v1/10359_1000365_adc.mha',
#   'Dataset_v1/10368_1000374_adc.mha',
#   'Dataset_v1/10378_1000384_adc.mha',
#   'Dataset_v1/10382_1000388_adc.mha',
#   'Dataset_v1/10385_1000391_adc.mha',
#   'Dataset_v1/10395_1000401_adc.mha',
#   'Dataset_v1/10400_1000406_adc.mha',
#   'Dataset_v1/10418_1000426_adc.mha',
#   'Dataset_v1/10427_1000435_adc.mha',
#   'Dataset_v1/10430_1000438_adc.mha',
#   'Dataset_v1/10438_1000446_adc.mha',
#   'Dataset_v1/10439_1000447_adc.mha',
#   'Dataset_v1/10449_1000457_adc.mha',
#   'Dataset_v1/10459_1000467_adc.mha',
#   'Dataset_v1/10463_1000471_adc.mha',
#   'Dataset_v1/10474_1000482_adc.mha',
#   'Dataset_v1/10479_1000487_adc.mha',
#   'Dataset_v1/10488_1000496_adc.mha',
#   'Dataset_v1/10501_1000510_adc.mha',
#   'Dataset_v1/10502_1000511_adc.mha',
#   'Dataset_v1/10515_1000525_adc.mha',
#   'Dataset_v1/10521_1000531_adc.mha',
#   'Dataset_v1/10525_1000535_adc.mha',
#   'Dataset_v1/10529_1000539_adc.mha',
#   'Dataset_v1/10533_1000543_adc.mha',
#   'Dataset_v1/10550_1000562_adc.mha',
#   'Dataset_v1/10562_1000574_adc.mha',
#   'Dataset_v1/10565_1000577_adc.mha',
#   'Dataset_v1/10568_1000580_adc.mha',
#   'Dataset_v1/10571_1000583_adc.mha',
#   'Dataset_v1/10583_1000597_adc.mha',
#   'Dataset_v1/10595_1000609_adc.mha',
#   'Dataset_v1/10599_1000613_adc.mha',
#   'Dataset_v1/10602_1000616_adc.mha',
#   'Dataset_v1/10617_1000631_adc.mha',
#   'Dataset_v1/10624_1000638_adc.mha',
#   'Dataset_v1/10632_1000647_adc.mha',
#   'Dataset_v1/10648_1000664_adc.mha',
#   'Dataset_v1/10667_1000683_adc.mha',
#   'Dataset_v1/10675_1000691_adc.mha',
#   'Dataset_v1/10679_1000695_adc.mha',
#   'Dataset_v1/10685_1000701_adc.mha',
#   'Dataset_v1/10699_1000715_adc.mha',
#   'Dataset_v1/10701_1000717_adc.mha',
#   'Dataset_v1/10711_1000727_adc.mha',
#   'Dataset_v1/10719_1000735_adc.mha',
#   'Dataset_v1/10726_1000742_adc.mha',
#   'Dataset_v1/10730_1000746_adc.mha',
#   'Dataset_v1/10736_1000752_adc.mha',
#   'Dataset_v1/10745_1000761_adc.mha',
#   'Dataset_v1/10751_1000767_adc.mha',
#   'Dataset_v1/10753_1000769_adc.mha',
#   'Dataset_v1/10760_1000776_adc.mha',
#   'Dataset_v1/10770_1000786_adc.mha',
#   'Dataset_v1/10772_1000788_adc.mha',
#   'Dataset_v1/10780_1000796_adc.mha',
#   'Dataset_v1/10782_1000798_adc.mha',
#   'Dataset_v1/10788_1000804_adc.mha',
#   'Dataset_v1/10791_1000807_adc.mha',
#   'Dataset_v1/10803_1000819_adc.mha',
#   'Dataset_v1/10834_1000850_adc.mha',
#   'Dataset_v1/10836_1000852_adc.mha',
#   'Dataset_v1/10839_1000855_adc.mha',
#   'Dataset_v1/10850_1000866_adc.mha',
#   'Dataset_v1/10851_1000867_adc.mha',
#   'Dataset_v1/10862_1000878_adc.mha',
#   'Dataset_v1/10871_1000887_adc.mha',
#   'Dataset_v1/10872_1000888_adc.mha',
#   'Dataset_v1/10879_1000895_adc.mha',
#   'Dataset_v1/10908_1000925_adc.mha',
#   'Dataset_v1/10922_1000939_adc.mha',
#   'Dataset_v1/10923_1000940_adc.mha',
#   'Dataset_v1/10929_1000946_adc.mha',
#   'Dataset_v1/10933_1000950_adc.mha',
#   'Dataset_v1/10934_1000951_adc.mha',
#   'Dataset_v1/10939_1000958_adc.mha',
#   'Dataset_v1/10942_1000961_adc.mha',
#   'Dataset_v1/10947_1000966_adc.mha',
#   'Dataset_v1/10956_1000975_adc.mha',
#   'Dataset_v1/10958_1000977_adc.mha',
#   'Dataset_v1/10961_1000980_adc.mha',
#   'Dataset_v1/10962_1000981_adc.mha',
#   'Dataset_v1/10964_1000983_adc.mha',
#   'Dataset_v1/10978_1000997_adc.mha',
#   'Dataset_v1/10982_1001001_adc.mha',
#   'Dataset_v1/10985_1001004_adc.mha',
#   'Dataset_v1/10990_1001009_adc.mha',
#   'Dataset_v1/10993_1001012_adc.mha',
#   'Dataset_v1/10994_1001013_adc.mha',
#   'Dataset_v1/10997_1001016_adc.mha',
#   'Dataset_v1/11002_1001021_adc.mha',
#   'Dataset_v1/11003_1001022_adc.mha',
#   'Dataset_v1/11007_1001027_adc.mha',
#   'Dataset_v1/11020_1001040_adc.mha',
#   'Dataset_v1/11035_1001055_adc.mha',
#   'Dataset_v1/11045_1001065_adc.mha',
#   'Dataset_v1/11057_1001078_adc.mha',
#   'Dataset_v1/11064_1001086_adc.mha',
#   'Dataset_v1/11067_1001089_adc.mha',
#   'Dataset_v1/11071_1001093_adc.mha',
#   'Dataset_v1/11079_1001101_adc.mha',
#   'Dataset_v1/11084_1001106_adc.mha',
#   'Dataset_v1/11086_1001108_adc.mha',
#   'Dataset_v1/11087_1001109_adc.mha',
#   'Dataset_v1/11087_1001110_adc.mha',
#   'Dataset_v1/11090_1001113_adc.mha',
#   'Dataset_v1/11094_1001117_adc.mha',
#   'Dataset_v1/11095_1001118_adc.mha',
#   'Dataset_v1/11099_1001122_adc.mha',
#   'Dataset_v1/11106_1001129_adc.mha',
#   'Dataset_v1/11111_1001134_adc.mha',
#   'Dataset_v1/11120_1001143_adc.mha',
#   'Dataset_v1/11125_1001148_adc.mha',
#   'Dataset_v1/11128_1001151_adc.mha',
#   'Dataset_v1/11135_1001158_adc.mha',
#   'Dataset_v1/11138_1001161_adc.mha',
#   'Dataset_v1/11144_1001167_adc.mha',
#   'Dataset_v1/11149_1001172_adc.mha',
#   'Dataset_v1/11151_1001174_adc.mha',
#   'Dataset_v1/11153_1001176_adc.mha',
#   'Dataset_v1/11157_1001180_adc.mha',
#   'Dataset_v1/11159_1001182_adc.mha',
#   'Dataset_v1/11161_1001184_adc.mha',
#   'Dataset_v1/11164_1001187_adc.mha',
#   'Dataset_v1/11165_1001188_adc.mha',
#   'Dataset_v1/11171_1001194_adc.mha',
#   'Dataset_v1/11173_1001196_adc.mha',
#   'Dataset_v1/11183_1001206_adc.mha',
#   'Dataset_v1/11196_1001219_adc.mha',
#   'Dataset_v1/11197_1001220_adc.mha',
#   'Dataset_v1/11198_1001221_adc.mha',
#   'Dataset_v1/11200_1001223_adc.mha',
#   'Dataset_v1/11212_1001235_adc.mha',
#   'Dataset_v1/11220_1001243_adc.mha',
#   'Dataset_v1/11221_1001244_adc.mha',
#   'Dataset_v1/11222_1001245_adc.mha',
#   'Dataset_v1/11231_1001254_adc.mha',
#   'Dataset_v1/11248_1001271_adc.mha',
#   'Dataset_v1/11249_1001272_adc.mha',
#   'Dataset_v1/11259_1001282_adc.mha',
#   'Dataset_v1/11266_1001289_adc.mha',
#   'Dataset_v1/11285_1001308_adc.mha',
#   'Dataset_v1/11294_1001317_adc.mha',
#   'Dataset_v1/11307_1001330_adc.mha',
#   'Dataset_v1/11313_1001336_adc.mha',
#   'Dataset_v1/11322_1001345_adc.mha',
#   'Dataset_v1/11330_1001353_adc.mha',
#   'Dataset_v1/11332_1001355_adc.mha',
#   'Dataset_v1/11334_1001357_adc.mha',
#   'Dataset_v1/11341_1001364_adc.mha',
#   'Dataset_v1/11346_1001369_adc.mha',
#   'Dataset_v1/11352_1001375_adc.mha',
#   'Dataset_v1/11353_1001376_adc.mha',
#   'Dataset_v1/11383_1001406_adc.mha',
#   'Dataset_v1/11383_1001407_adc.mha',
#   'Dataset_v1/11386_1001410_adc.mha',
#   'Dataset_v1/11389_1001413_adc.mha',
#   'Dataset_v1/11391_1001415_adc.mha',
#   'Dataset_v1/11400_1001424_adc.mha',
#   'Dataset_v1/11420_1001444_adc.mha',
#   'Dataset_v1/11425_1001449_adc.mha',
#   'Dataset_v1/11427_1001451_adc.mha',
#   'Dataset_v1/11451_1001475_adc.mha',
#   'Dataset_v1/11467_1001491_adc.mha',
#   'Dataset_v1/11469_1001493_adc.mha',
#   'Dataset_v1/11471_1001495_adc.mha',
#   'Dataset_v1/11473_1001497_adc.mha'],
#  'cor': ['Dataset_v1/10001_1000001_cor.mha',
#   'Dataset_v1/10006_1000006_cor.mha',
#   'Dataset_v1/10020_1000020_cor.mha',
#   'Dataset_v1/10023_1000023_cor.mha',
#   'Dataset_v1/10029_1000029_cor.mha',
#   'Dataset_v1/10032_1000032_cor.mha',
#   'Dataset_v1/10033_1000033_cor.mha',
#   'Dataset_v1/10038_1000038_cor.mha',
#   'Dataset_v1/10040_1000040_cor.mha',
#   'Dataset_v1/10059_1000059_cor.mha',
#   'Dataset_v1/10062_1000062_cor.mha',
#   'Dataset_v1/10071_1000071_cor.mha',
#   'Dataset_v1/10073_1000073_cor.mha',
#   'Dataset_v1/10078_1000078_cor.mha',
#   'Dataset_v1/10092_1000092_cor.mha',
#   'Dataset_v1/10129_1000129_cor.mha',
#   'Dataset_v1/10136_1000138_cor.mha',
#   'Dataset_v1/10146_1000148_cor.mha',
#   'Dataset_v1/10156_1000159_cor.mha',
#   'Dataset_v1/10158_1000161_cor.mha',
#   'Dataset_v1/10165_1000168_cor.mha',
#   'Dataset_v1/10167_1000170_cor.mha',
#   'Dataset_v1/10177_1000180_cor.mha',
#   'Dataset_v1/10189_1000192_cor.mha',
#   'Dataset_v1/10193_1000196_cor.mha',
#   'Dataset_v1/10195_1000199_cor.mha',
#   'Dataset_v1/10196_1000200_cor.mha',
#   'Dataset_v1/10197_1000201_cor.mha',
#   'Dataset_v1/10198_1000202_cor.mha',
#   'Dataset_v1/10229_1000233_cor.mha',
#   'Dataset_v1/10282_1000288_cor.mha',
#   'Dataset_v1/10298_1000304_cor.mha',
#   'Dataset_v1/10302_1000308_cor.mha',
#   'Dataset_v1/10310_1000316_cor.mha',
#   'Dataset_v1/10323_1000329_cor.mha',
#   'Dataset_v1/10326_1000332_cor.mha',
#   'Dataset_v1/10345_1000351_cor.mha',
#   'Dataset_v1/10352_1000358_cor.mha',
#   'Dataset_v1/10359_1000365_cor.mha',
#   'Dataset_v1/10368_1000374_cor.mha',
#   'Dataset_v1/10378_1000384_cor.mha',
#   'Dataset_v1/10382_1000388_cor.mha',
#   'Dataset_v1/10385_1000391_cor.mha',
#   'Dataset_v1/10395_1000401_cor.mha',
#   'Dataset_v1/10400_1000406_cor.mha',
#   'Dataset_v1/10418_1000426_cor.mha',
#   'Dataset_v1/10427_1000435_cor.mha',
#   'Dataset_v1/10430_1000438_cor.mha',
#   'Dataset_v1/10438_1000446_cor.mha',
#   'Dataset_v1/10439_1000447_cor.mha',
#   'Dataset_v1/10449_1000457_cor.mha',
#   'Dataset_v1/10459_1000467_cor.mha',
#   'Dataset_v1/10463_1000471_cor.mha',
#   'Dataset_v1/10474_1000482_cor.mha',
#   'Dataset_v1/10479_1000487_cor.mha',
#   'Dataset_v1/10488_1000496_cor.mha',
#   'Dataset_v1/10501_1000510_cor.mha',
#   'Dataset_v1/10502_1000511_cor.mha',
#   'Dataset_v1/10515_1000525_cor.mha',
#   'Dataset_v1/10521_1000531_cor.mha',
#   'Dataset_v1/10525_1000535_cor.mha',
#   'Dataset_v1/10529_1000539_cor.mha',
#   'Dataset_v1/10533_1000543_cor.mha',
#   'Dataset_v1/10550_1000562_cor.mha',
#   'Dataset_v1/10562_1000574_cor.mha',
#   'Dataset_v1/10565_1000577_cor.mha',
#   'Dataset_v1/10568_1000580_cor.mha',
#   'Dataset_v1/10571_1000583_cor.mha',
#   'Dataset_v1/10583_1000597_cor.mha',
#   'Dataset_v1/10595_1000609_cor.mha',
#   'Dataset_v1/10599_1000613_cor.mha',
#   'Dataset_v1/10602_1000616_cor.mha',
#   'Dataset_v1/10617_1000631_cor.mha',
#   'Dataset_v1/10624_1000638_cor.mha',
#   'Dataset_v1/10632_1000647_cor.mha',
#   'Dataset_v1/10648_1000664_cor.mha',
#   'Dataset_v1/10667_1000683_cor.mha',
#   'Dataset_v1/10675_1000691_cor.mha',
#   'Dataset_v1/10679_1000695_cor.mha',
#   'Dataset_v1/10685_1000701_cor.mha',
#   'Dataset_v1/10699_1000715_cor.mha',
#   'Dataset_v1/10701_1000717_cor.mha',
#   'Dataset_v1/10711_1000727_cor.mha',
#   'Dataset_v1/10719_1000735_cor.mha',
#   'Dataset_v1/10726_1000742_cor.mha',
#   'Dataset_v1/10730_1000746_cor.mha',
#   'Dataset_v1/10736_1000752_cor.mha',
#   'Dataset_v1/10745_1000761_cor.mha',
#   'Dataset_v1/10751_1000767_cor.mha',
#   'Dataset_v1/10753_1000769_cor.mha',
#   'Dataset_v1/10760_1000776_cor.mha',
#   'Dataset_v1/10770_1000786_cor.mha',
#   'Dataset_v1/10772_1000788_cor.mha',
#   'Dataset_v1/10780_1000796_cor.mha',
#   'Dataset_v1/10782_1000798_cor.mha',
#   'Dataset_v1/10788_1000804_cor.mha',
#   'Dataset_v1/10791_1000807_cor.mha',
#   'Dataset_v1/10803_1000819_cor.mha',
#   'Dataset_v1/10834_1000850_cor.mha',
#   'Dataset_v1/10836_1000852_cor.mha',
#   'Dataset_v1/10839_1000855_cor.mha',
#   'Dataset_v1/10850_1000866_cor.mha',
#   'Dataset_v1/10851_1000867_cor.mha',
#   'Dataset_v1/10862_1000878_cor.mha',
#   'Dataset_v1/10871_1000887_cor.mha',
#   'Dataset_v1/10872_1000888_cor.mha',
#   'Dataset_v1/10879_1000895_cor.mha',
#   'Dataset_v1/10908_1000925_cor.mha',
#   'Dataset_v1/10922_1000939_cor.mha',
#   'Dataset_v1/10923_1000940_cor.mha',
#   'Dataset_v1/10929_1000946_cor.mha',
#   'Dataset_v1/10933_1000950_cor.mha',
#   'Dataset_v1/10934_1000951_cor.mha',
#   'Dataset_v1/10939_1000958_cor.mha',
#   'Dataset_v1/10942_1000961_cor.mha',
#   'Dataset_v1/10947_1000966_cor.mha',
#   'Dataset_v1/10956_1000975_cor.mha',
#   'Dataset_v1/10958_1000977_cor.mha',
#   'Dataset_v1/10961_1000980_cor.mha',
#   'Dataset_v1/10962_1000981_cor.mha',
#   'Dataset_v1/10964_1000983_cor.mha',
#   'Dataset_v1/10978_1000997_cor.mha',
#   'Dataset_v1/10982_1001001_cor.mha',
#   'Dataset_v1/10985_1001004_cor.mha',
#   'Dataset_v1/10990_1001009_cor.mha',
#   'Dataset_v1/10993_1001012_cor.mha',
#   'Dataset_v1/10994_1001013_cor.mha',
#   'Dataset_v1/10997_1001016_cor.mha',
#   'Dataset_v1/11002_1001021_cor.mha',
#   'Dataset_v1/11003_1001022_cor.mha',
#   'Dataset_v1/11007_1001027_cor.mha',
#   'Dataset_v1/11020_1001040_cor.mha',
#   'Dataset_v1/11035_1001055_cor.mha',
#   'Dataset_v1/11045_1001065_cor.mha',
#   'Dataset_v1/11057_1001078_cor.mha',
#   'Dataset_v1/11064_1001086_cor.mha',
#   'Dataset_v1/11067_1001089_cor.mha',
#   'Dataset_v1/11071_1001093_cor.mha',
#   'Dataset_v1/11079_1001101_cor.mha',
#   'Dataset_v1/11084_1001106_cor.mha',
#   'Dataset_v1/11086_1001108_cor.mha',
#   'Dataset_v1/11087_1001109_cor.mha',
#   'Dataset_v1/11087_1001110_cor.mha',
#   'Dataset_v1/11090_1001113_cor.mha',
#   'Dataset_v1/11094_1001117_cor.mha',
#   'Dataset_v1/11095_1001118_cor.mha',
#   'Dataset_v1/11099_1001122_cor.mha',
#   'Dataset_v1/11106_1001129_cor.mha',
#   'Dataset_v1/11111_1001134_cor.mha',
#   'Dataset_v1/11120_1001143_cor.mha',
#   'Dataset_v1/11125_1001148_cor.mha',
#   'Dataset_v1/11128_1001151_cor.mha',
#   'Dataset_v1/11135_1001158_cor.mha',
#   'Dataset_v1/11138_1001161_cor.mha',
#   'Dataset_v1/11144_1001167_cor.mha',
#   'Dataset_v1/11149_1001172_cor.mha',
#   'Dataset_v1/11151_1001174_cor.mha',
#   'Dataset_v1/11153_1001176_cor.mha',
#   'Dataset_v1/11157_1001180_cor.mha',
#   'Dataset_v1/11159_1001182_cor.mha',
#   'Dataset_v1/11161_1001184_cor.mha',
#   'Dataset_v1/11164_1001187_cor.mha',
#   'Dataset_v1/11165_1001188_cor.mha',
#   'Dataset_v1/11171_1001194_cor.mha',
#   'Dataset_v1/11173_1001196_cor.mha',
#   'Dataset_v1/11183_1001206_cor.mha',
#   'Dataset_v1/11196_1001219_cor.mha',
#   'Dataset_v1/11197_1001220_cor.mha',
#   'Dataset_v1/11198_1001221_cor.mha',
#   'Dataset_v1/11200_1001223_cor.mha',
#   'Dataset_v1/11212_1001235_cor.mha',
#   'Dataset_v1/11220_1001243_cor.mha',
#   'Dataset_v1/11221_1001244_cor.mha',
#   'Dataset_v1/11222_1001245_cor.mha',
#   'Dataset_v1/11231_1001254_cor.mha',
#   'Dataset_v1/11248_1001271_cor.mha',
#   'Dataset_v1/11249_1001272_cor.mha',
#   'Dataset_v1/11259_1001282_cor.mha',
#   'Dataset_v1/11266_1001289_cor.mha',
#   'Dataset_v1/11285_1001308_cor.mha',
#   'Dataset_v1/11294_1001317_cor.mha',
#   'Dataset_v1/11307_1001330_cor.mha',
#   'Dataset_v1/11313_1001336_cor.mha',
#   'Dataset_v1/11322_1001345_cor.mha',
#   'Dataset_v1/11330_1001353_cor.mha',
#   'Dataset_v1/11332_1001355_cor.mha',
#   'Dataset_v1/11334_1001357_cor.mha',
#   'Dataset_v1/11341_1001364_cor.mha',
#   'Dataset_v1/11346_1001369_cor.mha',
#   'Dataset_v1/11352_1001375_cor.mha',
#   'Dataset_v1/11353_1001376_cor.mha',
#   'Dataset_v1/11383_1001406_cor.mha',
#   'Dataset_v1/11383_1001407_cor.mha',
#   'Dataset_v1/11386_1001410_cor.mha',
#   'Dataset_v1/11389_1001413_cor.mha',
#   'Dataset_v1/11391_1001415_cor.mha',
#   'Dataset_v1/11400_1001424_cor.mha',
#   'Dataset_v1/11420_1001444_cor.mha',
#   'Dataset_v1/11425_1001449_cor.mha',
#   'Dataset_v1/11427_1001451_cor.mha',
#   'Dataset_v1/11451_1001475_cor.mha',
#   'Dataset_v1/11467_1001491_cor.mha',
#   'Dataset_v1/11469_1001493_cor.mha',
#   'Dataset_v1/11471_1001495_cor.mha',
#   'Dataset_v1/11473_1001497_cor.mha'],
#  'hbv': ['Dataset_v1/10001_1000001_hbv.mha',
#   'Dataset_v1/10006_1000006_hbv.mha',
#   'Dataset_v1/10020_1000020_hbv.mha',
#   'Dataset_v1/10023_1000023_hbv.mha',
#   'Dataset_v1/10029_1000029_hbv.mha',
#   'Dataset_v1/10032_1000032_hbv.mha',
#   'Dataset_v1/10033_1000033_hbv.mha',
#   'Dataset_v1/10038_1000038_hbv.mha',
#   'Dataset_v1/10040_1000040_hbv.mha',
#   'Dataset_v1/10059_1000059_hbv.mha',
#   'Dataset_v1/10062_1000062_hbv.mha',
#   'Dataset_v1/10071_1000071_hbv.mha',
#   'Dataset_v1/10073_1000073_hbv.mha',
#   'Dataset_v1/10078_1000078_hbv.mha',
#   'Dataset_v1/10092_1000092_hbv.mha',
#   'Dataset_v1/10129_1000129_hbv.mha',
#   'Dataset_v1/10136_1000138_hbv.mha',
#   'Dataset_v1/10146_1000148_hbv.mha',
#   'Dataset_v1/10156_1000159_hbv.mha',
#   'Dataset_v1/10158_1000161_hbv.mha',
#   'Dataset_v1/10165_1000168_hbv.mha',
#   'Dataset_v1/10167_1000170_hbv.mha',
#   'Dataset_v1/10177_1000180_hbv.mha',
#   'Dataset_v1/10189_1000192_hbv.mha',
#   'Dataset_v1/10193_1000196_hbv.mha',
#   'Dataset_v1/10195_1000199_hbv.mha',
#   'Dataset_v1/10196_1000200_hbv.mha',
#   'Dataset_v1/10197_1000201_hbv.mha',
#   'Dataset_v1/10198_1000202_hbv.mha',
#   'Dataset_v1/10229_1000233_hbv.mha',
#   'Dataset_v1/10282_1000288_hbv.mha',
#   'Dataset_v1/10298_1000304_hbv.mha',
#   'Dataset_v1/10302_1000308_hbv.mha',
#   'Dataset_v1/10310_1000316_hbv.mha',
#   'Dataset_v1/10323_1000329_hbv.mha',
#   'Dataset_v1/10326_1000332_hbv.mha',
#   'Dataset_v1/10345_1000351_hbv.mha',
#   'Dataset_v1/10352_1000358_hbv.mha',
#   'Dataset_v1/10359_1000365_hbv.mha',
#   'Dataset_v1/10368_1000374_hbv.mha',
#   'Dataset_v1/10378_1000384_hbv.mha',
#   'Dataset_v1/10382_1000388_hbv.mha',
#   'Dataset_v1/10385_1000391_hbv.mha',
#   'Dataset_v1/10395_1000401_hbv.mha',
#   'Dataset_v1/10400_1000406_hbv.mha',
#   'Dataset_v1/10418_1000426_hbv.mha',
#   'Dataset_v1/10427_1000435_hbv.mha',
#   'Dataset_v1/10430_1000438_hbv.mha',
#   'Dataset_v1/10438_1000446_hbv.mha',
#   'Dataset_v1/10439_1000447_hbv.mha',
#   'Dataset_v1/10449_1000457_hbv.mha',
#   'Dataset_v1/10459_1000467_hbv.mha',
#   'Dataset_v1/10463_1000471_hbv.mha',
#   'Dataset_v1/10474_1000482_hbv.mha',
#   'Dataset_v1/10479_1000487_hbv.mha',
#   'Dataset_v1/10488_1000496_hbv.mha',
#   'Dataset_v1/10501_1000510_hbv.mha',
#   'Dataset_v1/10502_1000511_hbv.mha',
#   'Dataset_v1/10515_1000525_hbv.mha',
#   'Dataset_v1/10521_1000531_hbv.mha',
#   'Dataset_v1/10525_1000535_hbv.mha',
#   'Dataset_v1/10529_1000539_hbv.mha',
#   'Dataset_v1/10533_1000543_hbv.mha',
#   'Dataset_v1/10550_1000562_hbv.mha',
#   'Dataset_v1/10562_1000574_hbv.mha',
#   'Dataset_v1/10565_1000577_hbv.mha',
#   'Dataset_v1/10568_1000580_hbv.mha',
#   'Dataset_v1/10571_1000583_hbv.mha',
#   'Dataset_v1/10583_1000597_hbv.mha',
#   'Dataset_v1/10595_1000609_hbv.mha',
#   'Dataset_v1/10599_1000613_hbv.mha',
#   'Dataset_v1/10602_1000616_hbv.mha',
#   'Dataset_v1/10617_1000631_hbv.mha',
#   'Dataset_v1/10624_1000638_hbv.mha',
#   'Dataset_v1/10632_1000647_hbv.mha',
#   'Dataset_v1/10648_1000664_hbv.mha',
#   'Dataset_v1/10667_1000683_hbv.mha',
#   'Dataset_v1/10675_1000691_hbv.mha',
#   'Dataset_v1/10679_1000695_hbv.mha',
#   'Dataset_v1/10685_1000701_hbv.mha',
#   'Dataset_v1/10699_1000715_hbv.mha',
#   'Dataset_v1/10701_1000717_hbv.mha',
#   'Dataset_v1/10711_1000727_hbv.mha',
#   'Dataset_v1/10719_1000735_hbv.mha',
#   'Dataset_v1/10726_1000742_hbv.mha',
#   'Dataset_v1/10730_1000746_hbv.mha',
#   'Dataset_v1/10736_1000752_hbv.mha',
#   'Dataset_v1/10745_1000761_hbv.mha',
#   'Dataset_v1/10751_1000767_hbv.mha',
#   'Dataset_v1/10753_1000769_hbv.mha',
#   'Dataset_v1/10760_1000776_hbv.mha',
#   'Dataset_v1/10770_1000786_hbv.mha',
#   'Dataset_v1/10772_1000788_hbv.mha',
#   'Dataset_v1/10780_1000796_hbv.mha',
#   'Dataset_v1/10782_1000798_hbv.mha',
#   'Dataset_v1/10788_1000804_hbv.mha',
#   'Dataset_v1/10791_1000807_hbv.mha',
#   'Dataset_v1/10803_1000819_hbv.mha',
#   'Dataset_v1/10834_1000850_hbv.mha',
#   'Dataset_v1/10836_1000852_hbv.mha',
#   'Dataset_v1/10839_1000855_hbv.mha',
#   'Dataset_v1/10850_1000866_hbv.mha',
#   'Dataset_v1/10851_1000867_hbv.mha',
#   'Dataset_v1/10862_1000878_hbv.mha',
#   'Dataset_v1/10871_1000887_hbv.mha',
#   'Dataset_v1/10872_1000888_hbv.mha',
#   'Dataset_v1/10879_1000895_hbv.mha',
#   'Dataset_v1/10908_1000925_hbv.mha',
#   'Dataset_v1/10922_1000939_hbv.mha',
#   'Dataset_v1/10923_1000940_hbv.mha',
#   'Dataset_v1/10929_1000946_hbv.mha',
#   'Dataset_v1/10933_1000950_hbv.mha',
#   'Dataset_v1/10934_1000951_hbv.mha',
#   'Dataset_v1/10939_1000958_hbv.mha',
#   'Dataset_v1/10942_1000961_hbv.mha',
#   'Dataset_v1/10947_1000966_hbv.mha',
#   'Dataset_v1/10956_1000975_hbv.mha',
#   'Dataset_v1/10958_1000977_hbv.mha',
#   'Dataset_v1/10961_1000980_hbv.mha',
#   'Dataset_v1/10962_1000981_hbv.mha',
#   'Dataset_v1/10964_1000983_hbv.mha',
#   'Dataset_v1/10978_1000997_hbv.mha',
#   'Dataset_v1/10982_1001001_hbv.mha',
#   'Dataset_v1/10985_1001004_hbv.mha',
#   'Dataset_v1/10990_1001009_hbv.mha',
#   'Dataset_v1/10993_1001012_hbv.mha',
#   'Dataset_v1/10994_1001013_hbv.mha',
#   'Dataset_v1/10997_1001016_hbv.mha',
#   'Dataset_v1/11002_1001021_hbv.mha',
#   'Dataset_v1/11003_1001022_hbv.mha',
#   'Dataset_v1/11007_1001027_hbv.mha',
#   'Dataset_v1/11020_1001040_hbv.mha',
#   'Dataset_v1/11035_1001055_hbv.mha',
#   'Dataset_v1/11045_1001065_hbv.mha',
#   'Dataset_v1/11057_1001078_hbv.mha',
#   'Dataset_v1/11064_1001086_hbv.mha',
#   'Dataset_v1/11067_1001089_hbv.mha',
#   'Dataset_v1/11071_1001093_hbv.mha',
#   'Dataset_v1/11079_1001101_hbv.mha',
#   'Dataset_v1/11084_1001106_hbv.mha',
#   'Dataset_v1/11086_1001108_hbv.mha',
#   'Dataset_v1/11087_1001109_hbv.mha',
#   'Dataset_v1/11087_1001110_hbv.mha',
#   'Dataset_v1/11090_1001113_hbv.mha',
#   'Dataset_v1/11094_1001117_hbv.mha',
#   'Dataset_v1/11095_1001118_hbv.mha',
#   'Dataset_v1/11099_1001122_hbv.mha',
#   'Dataset_v1/11106_1001129_hbv.mha',
#   'Dataset_v1/11111_1001134_hbv.mha',
#   'Dataset_v1/11120_1001143_hbv.mha',
#   'Dataset_v1/11125_1001148_hbv.mha',
#   'Dataset_v1/11128_1001151_hbv.mha',
#   'Dataset_v1/11135_1001158_hbv.mha',
#   'Dataset_v1/11138_1001161_hbv.mha',
#   'Dataset_v1/11144_1001167_hbv.mha',
#   'Dataset_v1/11149_1001172_hbv.mha',
#   'Dataset_v1/11151_1001174_hbv.mha',
#   'Dataset_v1/11153_1001176_hbv.mha',
#   'Dataset_v1/11157_1001180_hbv.mha',
#   'Dataset_v1/11159_1001182_hbv.mha',
#   'Dataset_v1/11161_1001184_hbv.mha',
#   'Dataset_v1/11164_1001187_hbv.mha',
#   'Dataset_v1/11165_1001188_hbv.mha',
#   'Dataset_v1/11171_1001194_hbv.mha',
#   'Dataset_v1/11173_1001196_hbv.mha',
#   'Dataset_v1/11183_1001206_hbv.mha',
#   'Dataset_v1/11196_1001219_hbv.mha',
#   'Dataset_v1/11197_1001220_hbv.mha',
#   'Dataset_v1/11198_1001221_hbv.mha',
#   'Dataset_v1/11200_1001223_hbv.mha',
#   'Dataset_v1/11212_1001235_hbv.mha',
#   'Dataset_v1/11220_1001243_hbv.mha',
#   'Dataset_v1/11221_1001244_hbv.mha',
#   'Dataset_v1/11222_1001245_hbv.mha',
#   'Dataset_v1/11231_1001254_hbv.mha',
#   'Dataset_v1/11248_1001271_hbv.mha',
#   'Dataset_v1/11249_1001272_hbv.mha',
#   'Dataset_v1/11259_1001282_hbv.mha',
#   'Dataset_v1/11266_1001289_hbv.mha',
#   'Dataset_v1/11285_1001308_hbv.mha',
#   'Dataset_v1/11294_1001317_hbv.mha',
#   'Dataset_v1/11307_1001330_hbv.mha',
#   'Dataset_v1/11313_1001336_hbv.mha',
#   'Dataset_v1/11322_1001345_hbv.mha',
#   'Dataset_v1/11330_1001353_hbv.mha',
#   'Dataset_v1/11332_1001355_hbv.mha',
#   'Dataset_v1/11334_1001357_hbv.mha',
#   'Dataset_v1/11341_1001364_hbv.mha',
#   'Dataset_v1/11346_1001369_hbv.mha',
#   'Dataset_v1/11352_1001375_hbv.mha',
#   'Dataset_v1/11353_1001376_hbv.mha',
#   'Dataset_v1/11383_1001406_hbv.mha',
#   'Dataset_v1/11383_1001407_hbv.mha',
#   'Dataset_v1/11386_1001410_hbv.mha',
#   'Dataset_v1/11389_1001413_hbv.mha',
#   'Dataset_v1/11391_1001415_hbv.mha',
#   'Dataset_v1/11400_1001424_hbv.mha',
#   'Dataset_v1/11420_1001444_hbv.mha',
#   'Dataset_v1/11425_1001449_hbv.mha',
#   'Dataset_v1/11427_1001451_hbv.mha',
#   'Dataset_v1/11451_1001475_hbv.mha',
#   'Dataset_v1/11467_1001491_hbv.mha',
#   'Dataset_v1/11469_1001493_hbv.mha',
#   'Dataset_v1/11471_1001495_hbv.mha',
#   'Dataset_v1/11473_1001497_hbv.mha'],
#  'sag': ['Dataset_v1/10001_1000001_sag.mha',
#   'Dataset_v1/10006_1000006_sag.mha',
#   'Dataset_v1/10020_1000020_sag.mha',
#   'Dataset_v1/10023_1000023_sag.mha',
#   'Dataset_v1/10029_1000029_sag.mha',
#   'Dataset_v1/10032_1000032_sag.mha',
#   'Dataset_v1/10033_1000033_sag.mha',
#   'Dataset_v1/10038_1000038_sag.mha',
#   'Dataset_v1/10040_1000040_sag.mha',
#   'Dataset_v1/10059_1000059_sag.mha',
#   'Dataset_v1/10062_1000062_sag.mha',
#   'Dataset_v1/10071_1000071_sag.mha',
#   'Dataset_v1/10073_1000073_sag.mha',
#   'Dataset_v1/10078_1000078_sag.mha',
#   'Dataset_v1/10092_1000092_sag.mha',
#   'Dataset_v1/10129_1000129_sag.mha',
#   'Dataset_v1/10136_1000138_sag.mha',
#   'Dataset_v1/10146_1000148_sag.mha',
#   'Dataset_v1/10156_1000159_sag.mha',
#   'Dataset_v1/10158_1000161_sag.mha',
#   'Dataset_v1/10165_1000168_sag.mha',
#   'Dataset_v1/10167_1000170_sag.mha',
#   'Dataset_v1/10177_1000180_sag.mha',
#   'Dataset_v1/10189_1000192_sag.mha',
#   'Dataset_v1/10193_1000196_sag.mha',
#   'Dataset_v1/10195_1000199_sag.mha',
#   'Dataset_v1/10196_1000200_sag.mha',
#   'Dataset_v1/10197_1000201_sag.mha',
#   'Dataset_v1/10198_1000202_sag.mha',
#   'Dataset_v1/10229_1000233_sag.mha',
#   'Dataset_v1/10282_1000288_sag.mha',
#   'Dataset_v1/10298_1000304_sag.mha',
#   'Dataset_v1/10302_1000308_sag.mha',
#   'Dataset_v1/10310_1000316_sag.mha',
#   'Dataset_v1/10323_1000329_sag.mha',
#   'Dataset_v1/10326_1000332_sag.mha',
#   'Dataset_v1/10345_1000351_sag.mha',
#   'Dataset_v1/10352_1000358_sag.mha',
#   'Dataset_v1/10359_1000365_sag.mha',
#   'Dataset_v1/10368_1000374_sag.mha',
#   'Dataset_v1/10378_1000384_sag.mha',
#   'Dataset_v1/10382_1000388_sag.mha',
#   'Dataset_v1/10385_1000391_sag.mha',
#   'Dataset_v1/10395_1000401_sag.mha',
#   'Dataset_v1/10400_1000406_sag.mha',
#   'Dataset_v1/10418_1000426_sag.mha',
#   'Dataset_v1/10427_1000435_sag.mha',
#   'Dataset_v1/10430_1000438_sag.mha',
#   'Dataset_v1/10438_1000446_sag.mha',
#   'Dataset_v1/10439_1000447_sag.mha',
#   'Dataset_v1/10449_1000457_sag.mha',
#   'Dataset_v1/10459_1000467_sag.mha',
#   'Dataset_v1/10463_1000471_sag.mha',
#   'Dataset_v1/10474_1000482_sag.mha',
#   'Dataset_v1/10479_1000487_sag.mha',
#   'Dataset_v1/10488_1000496_sag.mha',
#   'Dataset_v1/10501_1000510_sag.mha',
#   'Dataset_v1/10502_1000511_sag.mha',
#   'Dataset_v1/10515_1000525_sag.mha',
#   'Dataset_v1/10521_1000531_sag.mha',
#   'Dataset_v1/10525_1000535_sag.mha',
#   'Dataset_v1/10529_1000539_sag.mha',
#   'Dataset_v1/10533_1000543_sag.mha',
#   'Dataset_v1/10550_1000562_sag.mha',
#   'Dataset_v1/10562_1000574_sag.mha',
#   'Dataset_v1/10565_1000577_sag.mha',
#   'Dataset_v1/10568_1000580_sag.mha',
#   'Dataset_v1/10571_1000583_sag.mha',
#   'Dataset_v1/10583_1000597_sag.mha',
#   'Dataset_v1/10595_1000609_sag.mha',
#   'Dataset_v1/10599_1000613_sag.mha',
#   'Dataset_v1/10602_1000616_sag.mha',
#   'Dataset_v1/10617_1000631_sag.mha',
#   'Dataset_v1/10624_1000638_sag.mha',
#   'Dataset_v1/10632_1000647_sag.mha',
#   'Dataset_v1/10648_1000664_sag.mha',
#   'Dataset_v1/10667_1000683_sag.mha',
#   'Dataset_v1/10675_1000691_sag.mha',
#   'Dataset_v1/10679_1000695_sag.mha',
#   'Dataset_v1/10685_1000701_sag.mha',
#   'Dataset_v1/10699_1000715_sag.mha',
#   'Dataset_v1/10701_1000717_sag.mha',
#   'Dataset_v1/10711_1000727_sag.mha',
#   'Dataset_v1/10719_1000735_sag.mha',
#   'Dataset_v1/10726_1000742_sag.mha',
#   'Dataset_v1/10730_1000746_sag.mha',
#   'Dataset_v1/10736_1000752_sag.mha',
#   'Dataset_v1/10745_1000761_sag.mha',
#   'Dataset_v1/10751_1000767_sag.mha',
#   'Dataset_v1/10753_1000769_sag.mha',
#   'Dataset_v1/10760_1000776_sag.mha',
#   'Dataset_v1/10770_1000786_sag.mha',
#   'Dataset_v1/10772_1000788_sag.mha',
#   'Dataset_v1/10780_1000796_sag.mha',
#   'Dataset_v1/10782_1000798_sag.mha',
#   'Dataset_v1/10788_1000804_sag.mha',
#   'Dataset_v1/10791_1000807_sag.mha',
#   'Dataset_v1/10803_1000819_sag.mha',
#   'Dataset_v1/10834_1000850_sag.mha',
#   'Dataset_v1/10836_1000852_sag.mha',
#   'Dataset_v1/10839_1000855_sag.mha',
#   'Dataset_v1/10850_1000866_sag.mha',
#   'Dataset_v1/10851_1000867_sag.mha',
#   'Dataset_v1/10862_1000878_sag.mha',
#   'Dataset_v1/10871_1000887_sag.mha',
#   'Dataset_v1/10872_1000888_sag.mha',
#   'Dataset_v1/10879_1000895_sag.mha',
#   'Dataset_v1/10908_1000925_sag.mha',
#   'Dataset_v1/10922_1000939_sag.mha',
#   'Dataset_v1/10923_1000940_sag.mha',
#   'Dataset_v1/10929_1000946_sag.mha',
#   'Dataset_v1/10933_1000950_sag.mha',
#   'Dataset_v1/10934_1000951_sag.mha',
#   'Dataset_v1/10939_1000958_sag.mha',
#   'Dataset_v1/10942_1000961_sag.mha',
#   'Dataset_v1/10947_1000966_sag.mha',
#   'Dataset_v1/10956_1000975_sag.mha',
#   'Dataset_v1/10958_1000977_sag.mha',
#   'Dataset_v1/10961_1000980_sag.mha',
#   'Dataset_v1/10962_1000981_sag.mha',
#   'Dataset_v1/10964_1000983_sag.mha',
#   'Dataset_v1/10978_1000997_sag.mha',
#   'Dataset_v1/10982_1001001_sag.mha',
#   'Dataset_v1/10985_1001004_sag.mha',
#   'Dataset_v1/10990_1001009_sag.mha',
#   'Dataset_v1/10993_1001012_sag.mha',
#   'Dataset_v1/10994_1001013_sag.mha',
#   'Dataset_v1/10997_1001016_sag.mha',
#   'Dataset_v1/11002_1001021_sag.mha',
#   'Dataset_v1/11003_1001022_sag.mha',
#   'Dataset_v1/11007_1001027_sag.mha',
#   'Dataset_v1/11020_1001040_sag.mha',
#   'Dataset_v1/11035_1001055_sag.mha',
#   'Dataset_v1/11045_1001065_sag.mha',
#   'Dataset_v1/11057_1001078_sag.mha',
#   'Dataset_v1/11064_1001086_sag.mha',
#   'Dataset_v1/11067_1001089_sag.mha',
#   'Dataset_v1/11071_1001093_sag.mha',
#   'Dataset_v1/11079_1001101_sag.mha',
#   'Dataset_v1/11084_1001106_sag.mha',
#   'Dataset_v1/11086_1001108_sag.mha',
#   'Dataset_v1/11087_1001109_sag.mha',
#   'Dataset_v1/11087_1001110_sag.mha',
#   'Dataset_v1/11090_1001113_sag.mha',
#   'Dataset_v1/11094_1001117_sag.mha',
#   'Dataset_v1/11095_1001118_sag.mha',
#   'Dataset_v1/11099_1001122_sag.mha',
#   'Dataset_v1/11106_1001129_sag.mha',
#   'Dataset_v1/11111_1001134_sag.mha',
#   'Dataset_v1/11120_1001143_sag.mha',
#   'Dataset_v1/11125_1001148_sag.mha',
#   'Dataset_v1/11128_1001151_sag.mha',
#   'Dataset_v1/11135_1001158_sag.mha',
#   'Dataset_v1/11138_1001161_sag.mha',
#   'Dataset_v1/11144_1001167_sag.mha',
#   'Dataset_v1/11149_1001172_sag.mha',
#   'Dataset_v1/11151_1001174_sag.mha',
#   'Dataset_v1/11153_1001176_sag.mha',
#   'Dataset_v1/11157_1001180_sag.mha',
#   'Dataset_v1/11159_1001182_sag.mha',
#   'Dataset_v1/11161_1001184_sag.mha',
#   'Dataset_v1/11164_1001187_sag.mha',
#   'Dataset_v1/11165_1001188_sag.mha',
#   'Dataset_v1/11171_1001194_sag.mha',
#   'Dataset_v1/11173_1001196_sag.mha',
#   'Dataset_v1/11183_1001206_sag.mha',
#   'Dataset_v1/11196_1001219_sag.mha',
#   'Dataset_v1/11197_1001220_sag.mha',
#   'Dataset_v1/11198_1001221_sag.mha',
#   'Dataset_v1/11200_1001223_sag.mha',
#   'Dataset_v1/11212_1001235_sag.mha',
#   'Dataset_v1/11220_1001243_sag.mha',
#   'Dataset_v1/11221_1001244_sag.mha',
#   'Dataset_v1/11222_1001245_sag.mha',
#   'Dataset_v1/11231_1001254_sag.mha',
#   'Dataset_v1/11248_1001271_sag.mha',
#   'Dataset_v1/11249_1001272_sag.mha',
#   'Dataset_v1/11259_1001282_sag.mha',
#   'Dataset_v1/11266_1001289_sag.mha',
#   'Dataset_v1/11285_1001308_sag.mha',
#   'Dataset_v1/11294_1001317_sag.mha',
#   'Dataset_v1/11307_1001330_sag.mha',
#   'Dataset_v1/11313_1001336_sag.mha',
#   'Dataset_v1/11322_1001345_sag.mha',
#   'Dataset_v1/11330_1001353_sag.mha',
#   'Dataset_v1/11332_1001355_sag.mha',
#   'Dataset_v1/11334_1001357_sag.mha',
#   'Dataset_v1/11341_1001364_sag.mha',
#   'Dataset_v1/11346_1001369_sag.mha',
#   'Dataset_v1/11352_1001375_sag.mha',
#   'Dataset_v1/11353_1001376_sag.mha',
#   'Dataset_v1/11383_1001406_sag.mha',
#   'Dataset_v1/11383_1001407_sag.mha',
#   'Dataset_v1/11386_1001410_sag.mha',
#   'Dataset_v1/11389_1001413_sag.mha',
#   'Dataset_v1/11391_1001415_sag.mha',
#   'Dataset_v1/11400_1001424_sag.mha',
#   'Dataset_v1/11420_1001444_sag.mha',
#   'Dataset_v1/11425_1001449_sag.mha',
#   'Dataset_v1/11427_1001451_sag.mha',
#   'Dataset_v1/11451_1001475_sag.mha',
#   'Dataset_v1/11467_1001491_sag.mha',
#   'Dataset_v1/11469_1001493_sag.mha',
#   'Dataset_v1/11471_1001495_sag.mha',
#   'Dataset_v1/11473_1001497_sag.mha'],
#  't2w': ['Dataset_v1/10001_1000001_t2w.mha',
#   'Dataset_v1/10006_1000006_t2w.mha',
#   'Dataset_v1/10020_1000020_t2w.mha',
#   'Dataset_v1/10023_1000023_t2w.mha',
#   'Dataset_v1/10029_1000029_t2w.mha',
#   'Dataset_v1/10032_1000032_t2w.mha',
#   'Dataset_v1/10033_1000033_t2w.mha',
#   'Dataset_v1/10038_1000038_t2w.mha',
#   'Dataset_v1/10040_1000040_t2w.mha',
#   'Dataset_v1/10059_1000059_t2w.mha',
#   'Dataset_v1/10062_1000062_t2w.mha',
#   'Dataset_v1/10071_1000071_t2w.mha',
#   'Dataset_v1/10073_1000073_t2w.mha',
#   'Dataset_v1/10078_1000078_t2w.mha',
#   'Dataset_v1/10092_1000092_t2w.mha',
#   'Dataset_v1/10129_1000129_t2w.mha',
#   'Dataset_v1/10136_1000138_t2w.mha',
#   'Dataset_v1/10146_1000148_t2w.mha',
#   'Dataset_v1/10156_1000159_t2w.mha',
#   'Dataset_v1/10158_1000161_t2w.mha',
#   'Dataset_v1/10165_1000168_t2w.mha',
#   'Dataset_v1/10167_1000170_t2w.mha',
#   'Dataset_v1/10177_1000180_t2w.mha',
#   'Dataset_v1/10189_1000192_t2w.mha',
#   'Dataset_v1/10193_1000196_t2w.mha',
#   'Dataset_v1/10195_1000199_t2w.mha',
#   'Dataset_v1/10196_1000200_t2w.mha',
#   'Dataset_v1/10197_1000201_t2w.mha',
#   'Dataset_v1/10198_1000202_t2w.mha',
#   'Dataset_v1/10229_1000233_t2w.mha',
#   'Dataset_v1/10282_1000288_t2w.mha',
#   'Dataset_v1/10298_1000304_t2w.mha',
#   'Dataset_v1/10302_1000308_t2w.mha',
#   'Dataset_v1/10310_1000316_t2w.mha',
#   'Dataset_v1/10323_1000329_t2w.mha',
#   'Dataset_v1/10326_1000332_t2w.mha',
#   'Dataset_v1/10345_1000351_t2w.mha',
#   'Dataset_v1/10352_1000358_t2w.mha',
#   'Dataset_v1/10359_1000365_t2w.mha',
#   'Dataset_v1/10368_1000374_t2w.mha',
#   'Dataset_v1/10378_1000384_t2w.mha',
#   'Dataset_v1/10382_1000388_t2w.mha',
#   'Dataset_v1/10385_1000391_t2w.mha',
#   'Dataset_v1/10395_1000401_t2w.mha',
#   'Dataset_v1/10400_1000406_t2w.mha',
#   'Dataset_v1/10418_1000426_t2w.mha',
#   'Dataset_v1/10427_1000435_t2w.mha',
#   'Dataset_v1/10430_1000438_t2w.mha',
#   'Dataset_v1/10438_1000446_t2w.mha',
#   'Dataset_v1/10439_1000447_t2w.mha',
#   'Dataset_v1/10449_1000457_t2w.mha',
#   'Dataset_v1/10459_1000467_t2w.mha',
#   'Dataset_v1/10463_1000471_t2w.mha',
#   'Dataset_v1/10474_1000482_t2w.mha',
#   'Dataset_v1/10479_1000487_t2w.mha',
#   'Dataset_v1/10488_1000496_t2w.mha',
#   'Dataset_v1/10501_1000510_t2w.mha',
#   'Dataset_v1/10502_1000511_t2w.mha',
#   'Dataset_v1/10515_1000525_t2w.mha',
#   'Dataset_v1/10521_1000531_t2w.mha',
#   'Dataset_v1/10525_1000535_t2w.mha',
#   'Dataset_v1/10529_1000539_t2w.mha',
#   'Dataset_v1/10533_1000543_t2w.mha',
#   'Dataset_v1/10550_1000562_t2w.mha',
#   'Dataset_v1/10562_1000574_t2w.mha',
#   'Dataset_v1/10565_1000577_t2w.mha',
#   'Dataset_v1/10568_1000580_t2w.mha',
#   'Dataset_v1/10571_1000583_t2w.mha',
#   'Dataset_v1/10583_1000597_t2w.mha',
#   'Dataset_v1/10595_1000609_t2w.mha',
#   'Dataset_v1/10599_1000613_t2w.mha',
#   'Dataset_v1/10602_1000616_t2w.mha',
#   'Dataset_v1/10617_1000631_t2w.mha',
#   'Dataset_v1/10624_1000638_t2w.mha',
#   'Dataset_v1/10632_1000647_t2w.mha',
#   'Dataset_v1/10648_1000664_t2w.mha',
#   'Dataset_v1/10667_1000683_t2w.mha',
#   'Dataset_v1/10675_1000691_t2w.mha',
#   'Dataset_v1/10679_1000695_t2w.mha',
#   'Dataset_v1/10685_1000701_t2w.mha',
#   'Dataset_v1/10699_1000715_t2w.mha',
#   'Dataset_v1/10701_1000717_t2w.mha',
#   'Dataset_v1/10711_1000727_t2w.mha',
#   'Dataset_v1/10719_1000735_t2w.mha',
#   'Dataset_v1/10726_1000742_t2w.mha',
#   'Dataset_v1/10730_1000746_t2w.mha',
#   'Dataset_v1/10736_1000752_t2w.mha',
#   'Dataset_v1/10745_1000761_t2w.mha',
#   'Dataset_v1/10751_1000767_t2w.mha',
#   'Dataset_v1/10753_1000769_t2w.mha',
#   'Dataset_v1/10760_1000776_t2w.mha',
#   'Dataset_v1/10770_1000786_t2w.mha',
#   'Dataset_v1/10772_1000788_t2w.mha',
#   'Dataset_v1/10780_1000796_t2w.mha',
#   'Dataset_v1/10782_1000798_t2w.mha',
#   'Dataset_v1/10788_1000804_t2w.mha',
#   'Dataset_v1/10791_1000807_t2w.mha',
#   'Dataset_v1/10803_1000819_t2w.mha',
#   'Dataset_v1/10834_1000850_t2w.mha',
#   'Dataset_v1/10836_1000852_t2w.mha',
#   'Dataset_v1/10839_1000855_t2w.mha',
#   'Dataset_v1/10850_1000866_t2w.mha',
#   'Dataset_v1/10851_1000867_t2w.mha',
#   'Dataset_v1/10862_1000878_t2w.mha',
#   'Dataset_v1/10871_1000887_t2w.mha',
#   'Dataset_v1/10872_1000888_t2w.mha',
#   'Dataset_v1/10879_1000895_t2w.mha',
#   'Dataset_v1/10908_1000925_t2w.mha',
#   'Dataset_v1/10922_1000939_t2w.mha',
#   'Dataset_v1/10923_1000940_t2w.mha',
#   'Dataset_v1/10929_1000946_t2w.mha',
#   'Dataset_v1/10933_1000950_t2w.mha',
#   'Dataset_v1/10934_1000951_t2w.mha',
#   'Dataset_v1/10939_1000958_t2w.mha',
#   'Dataset_v1/10942_1000961_t2w.mha',
#   'Dataset_v1/10947_1000966_t2w.mha',
#   'Dataset_v1/10956_1000975_t2w.mha',
#   'Dataset_v1/10958_1000977_t2w.mha',
#   'Dataset_v1/10961_1000980_t2w.mha',
#   'Dataset_v1/10962_1000981_t2w.mha',
#   'Dataset_v1/10964_1000983_t2w.mha',
#   'Dataset_v1/10978_1000997_t2w.mha',
#   'Dataset_v1/10982_1001001_t2w.mha',
#   'Dataset_v1/10985_1001004_t2w.mha',
#   'Dataset_v1/10990_1001009_t2w.mha',
#   'Dataset_v1/10993_1001012_t2w.mha',
#   'Dataset_v1/10994_1001013_t2w.mha',
#   'Dataset_v1/10997_1001016_t2w.mha',
#   'Dataset_v1/11002_1001021_t2w.mha',
#   'Dataset_v1/11003_1001022_t2w.mha',
#   'Dataset_v1/11007_1001027_t2w.mha',
#   'Dataset_v1/11020_1001040_t2w.mha',
#   'Dataset_v1/11035_1001055_t2w.mha',
#   'Dataset_v1/11045_1001065_t2w.mha',
#   'Dataset_v1/11057_1001078_t2w.mha',
#   'Dataset_v1/11064_1001086_t2w.mha',
#   'Dataset_v1/11067_1001089_t2w.mha',
#   'Dataset_v1/11071_1001093_t2w.mha',
#   'Dataset_v1/11079_1001101_t2w.mha',
#   'Dataset_v1/11084_1001106_t2w.mha',
#   'Dataset_v1/11086_1001108_t2w.mha',
#   'Dataset_v1/11087_1001109_t2w.mha',
#   'Dataset_v1/11087_1001110_t2w.mha',
#   'Dataset_v1/11090_1001113_t2w.mha',
#   'Dataset_v1/11094_1001117_t2w.mha',
#   'Dataset_v1/11095_1001118_t2w.mha',
#   'Dataset_v1/11099_1001122_t2w.mha',
#   'Dataset_v1/11106_1001129_t2w.mha',
#   'Dataset_v1/11111_1001134_t2w.mha',
#   'Dataset_v1/11120_1001143_t2w.mha',
#   'Dataset_v1/11125_1001148_t2w.mha',
#   'Dataset_v1/11128_1001151_t2w.mha',
#   'Dataset_v1/11135_1001158_t2w.mha',
#   'Dataset_v1/11138_1001161_t2w.mha',
#   'Dataset_v1/11144_1001167_t2w.mha',
#   'Dataset_v1/11149_1001172_t2w.mha',
#   'Dataset_v1/11151_1001174_t2w.mha',
#   'Dataset_v1/11153_1001176_t2w.mha',
#   'Dataset_v1/11157_1001180_t2w.mha',
#   'Dataset_v1/11159_1001182_t2w.mha',
#   'Dataset_v1/11161_1001184_t2w.mha',
#   'Dataset_v1/11164_1001187_t2w.mha',
#   'Dataset_v1/11165_1001188_t2w.mha',
#   'Dataset_v1/11171_1001194_t2w.mha',
#   'Dataset_v1/11173_1001196_t2w.mha',
#   'Dataset_v1/11183_1001206_t2w.mha',
#   'Dataset_v1/11196_1001219_t2w.mha',
#   'Dataset_v1/11197_1001220_t2w.mha',
#   'Dataset_v1/11198_1001221_t2w.mha',
#   'Dataset_v1/11200_1001223_t2w.mha',
#   'Dataset_v1/11212_1001235_t2w.mha',
#   'Dataset_v1/11220_1001243_t2w.mha',
#   'Dataset_v1/11221_1001244_t2w.mha',
#   'Dataset_v1/11222_1001245_t2w.mha',
#   'Dataset_v1/11231_1001254_t2w.mha',
#   'Dataset_v1/11248_1001271_t2w.mha',
#   'Dataset_v1/11249_1001272_t2w.mha',
#   'Dataset_v1/11259_1001282_t2w.mha',
#   'Dataset_v1/11266_1001289_t2w.mha',
#   'Dataset_v1/11285_1001308_t2w.mha',
#   'Dataset_v1/11294_1001317_t2w.mha',
#   'Dataset_v1/11307_1001330_t2w.mha',
#   'Dataset_v1/11313_1001336_t2w.mha',
#   'Dataset_v1/11322_1001345_t2w.mha',
#   'Dataset_v1/11330_1001353_t2w.mha',
#   'Dataset_v1/11332_1001355_t2w.mha',
#   'Dataset_v1/11334_1001357_t2w.mha',
#   'Dataset_v1/11341_1001364_t2w.mha',
#   'Dataset_v1/11346_1001369_t2w.mha',
#   'Dataset_v1/11352_1001375_t2w.mha',
#   'Dataset_v1/11353_1001376_t2w.mha',
#   'Dataset_v1/11383_1001406_t2w.mha',
#   'Dataset_v1/11383_1001407_t2w.mha',
#   'Dataset_v1/11386_1001410_t2w.mha',
#   'Dataset_v1/11389_1001413_t2w.mha',
#   'Dataset_v1/11391_1001415_t2w.mha',
#   'Dataset_v1/11400_1001424_t2w.mha',
#   'Dataset_v1/11420_1001444_t2w.mha',
#   'Dataset_v1/11425_1001449_t2w.mha',
#   'Dataset_v1/11427_1001451_t2w.mha',
#   'Dataset_v1/11451_1001475_t2w.mha',
#   'Dataset_v1/11467_1001491_t2w.mha',
#   'Dataset_v1/11469_1001493_t2w.mha',
#   'Dataset_v1/11471_1001495_t2w.mha',
#   'Dataset_v1/11473_1001497_t2w.mha']}

# %%
df_adc['path'] = grouped_files['adc']
df_cor['path'] = grouped_files['cor']
df_hbv['path'] = grouped_files['hbv']
df_sag['path'] = grouped_files['sag']
df_t2w['path'] = grouped_files['t2w']

# %% [markdown]
# ## Histogram of Height, Width and channels of pics

# %%
def hdw(df):
    height = list()
    depth = list()
    width = list()

    for path in df['path']:
        image = sitk.ReadImage(path)
        height.append(image.GetHeight())
        depth.append(image.GetDepth())
        width.append(image.GetWidth())
    return height, depth, width

# %%
adc_h, adc_d, adc_w = hdw(df=df_adc)
cor_h, cor_d, cor_w = hdw(df=df_cor)
sag_h, sag_d, sag_w = hdw(df=df_sag)
t2w_h, t2w_d, t2w_w = hdw(df=df_t2w)
hbv_h, hbv_d, hbv_w = hdw(df=df_hbv)

# %%
def plot_hdw(h, d, w, df_name):
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.title(f'Histogram of height & width for {df_name}')
    plt.xlabel('height/width(No.pixel)')
    sns.histplot(h, kde=True)
    sns.histplot(w, kde=True)
    plt.legend(['height', 'width'])

    plt.subplot(1, 2, 2)
    plt.title(f"Histogram of channels for {df_name}")
    plt.xlabel("channels")
    sns.histplot(d, kde=True)

    plt.tight_layout()
    plt.show()

# %%
plot_hdw(adc_h, adc_d, adc_w, 'df_adc')
plot_hdw(cor_h, cor_d, cor_w, 'df_cor')
plot_hdw(sag_h, sag_d, sag_w, 'df_sag')
plot_hdw(t2w_h, t2w_d, t2w_w, 'df_t2w')
plot_hdw(hbv_h, hbv_d, hbv_w, 'df_hbv')

# %% [markdown]
# ## Add Label to Dataframe

# %%
marksheet = pd.read_csv("marksheet.csv")
marksheet.set_index("study_id", inplace=True)
label = marksheet["case_csPCa"]
for i in range(len(label)):
    if label.iloc[i] == "NO":
        label.iloc[i] = 0
    else:
        label.iloc[i] = 1
label
# Out:
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 0
# /tmp/ipykernel_12122/1875267677.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label.iloc[i] = 1
# study_id
# 1000000    0
# 1000001    0
# 1000002    0
# 1000003    0
# 1000004    0
#           ..
# 1001495    1
# 1001496    1
# 1001497    0
# 1001498    0
# 1001499    1
# Name: case_csPCa, Length: 1500, dtype: object

# %% [markdown]
# ## Image Normalization

# %%
def show_hist_origin_scaled_slides(image_array, scaler = "origin"):
    shape = image_array.shape
    slides = list()

    if scaler == 'origin':
        plt.figure(figsize=(10, 5))
        plt.title("hist of intensity for adc_pic0")
        for slide in range(shape[0]):
            sns.histplot(image_array[slide, :, :].flatten(), kde=True, alpha = 0.3)
            slides.append(f"slide{slide}")
        plt.xlabel("Intensity")
        plt.legend(slides)
    elif scaler == "min_max":
        plt.figure(figsize=(10, 5))
        plt.title("hist of intensity for adc_pic0 (min_max_scaler)")
        min_max = MinMaxScaler()
        for slide in range(shape[0]):
            image_array_minmaxscaled = min_max.fit_transform(image_array[slide, :, :])
            sns.histplot(image_array_minmaxscaled.flatten(), kde=True, alpha = 0.3)
            slides.append(f"slide{slide}")
        plt.xlabel("Intensity")
        plt.legend(slides)
    elif scaler == "standard":
        standard = StandardScaler()
        plt.figure(figsize=(10, 5))
        plt.title("hist of intensity for adc_pic0 (standard_scaler)")
        for slide in range(shape[0]):
            image_array_minmaxscaled = standard.fit_transform(image_array[slide, :, :])
            sns.histplot(image_array_minmaxscaled.flatten(), kde=True, alpha = 0.3)
            slides.append(f"slide{slide}")
        plt.xlabel("Intensity")
        plt.legend(slides)
    elif scaler == "maxabs":
        standard = MaxAbsScaler()
        plt.figure(figsize=(10, 5))
        plt.title("hist of intensity for adc_pic0 (maxabs)")
        for slide in range(shape[0]):
            image_array_minmaxscaled = standard.fit_transform(image_array[slide, :, :])
            sns.histplot(image_array_minmaxscaled.flatten(), kde=True, alpha = 0.3)
            slides.append(f"slide{slide}")
        plt.xlabel("Intensity")
        plt.legend(slides)
    elif scaler == "robust":
        standard = RobustScaler()
        plt.figure(figsize=(10, 5))
        plt.title("hist of intensity for adc_pic0 (robust)")
        for slide in range(shape[0]):
            image_array_minmaxscaled = standard.fit_transform(image_array[slide, :, :])
            sns.histplot(image_array_minmaxscaled.flatten(), kde=True, alpha = 0.3)
            slides.append(f"slide{slide}")
        plt.xlabel("Intensity")
        plt.legend(slides)
    plt.tight_layout()
    plt.show()

# %%
image = sitk.ReadImage(grouped_files['t2w'][0])
image_array = sitk.GetArrayFromImage(image)

show_hist_origin_scaled_slides(image_array=image_array)

show_hist_origin_scaled_slides(image_array=image_array, scaler='min_max')

show_hist_origin_scaled_slides(scaler="standard", image_array=image_array)

show_hist_origin_scaled_slides(scaler="robust", image_array=image_array)

show_hist_origin_scaled_slides(scaler="maxabs", image_array=image_array)

# %%
def rescale_images(image):
    filter = sitk.RescaleIntensityImageFilter()
    filter.SetOutputMaximum(255)
    filter.SetOutputMinimum(0)
    rescaled_image = filter.Execute(image)
    return rescaled_image

# %%
def show_hist_intensity(df_name, numbers, scaler = 'origin'):
    scaled = list()
    plt.figure(figsize=(10, 5))
    if scaler == 'origin':
        plt.title(f"Histogram of Intensity for {df_name}")
        for pic in range(numbers):
            image = sitk.ReadImage(grouped_files[df_name][pic])
            rescaled_image = rescale_images(image=image)
            image_array = sitk.GetArrayFromImage(rescaled_image)
            sns.histplot(image_array[0, :, :].flatten(), kde=True, alpha=0.3)
    elif scaler == 'standard':
        scaler = StandardScaler()
        plt.title(f"Histogram of Intensity for {df_name} (standard_scaled)")
        for pic in range(numbers):
            image = sitk.ReadImage(grouped_files[df_name][pic])
            rescaled_image = rescale_images(image=image)
            image_array = sitk.GetArrayFromImage(rescaled_image)
            scaled = scaler.fit_transform(image_array[0, :, :])
            sns.histplot(scaled.flatten(), kde=True, alpha=0.3)
    elif scaler == 'minmax':
        scaler = MinMaxScaler()
        plt.title(f"Histogram of Intensity for {df_name} (min_max)")
        for pic in range(numbers):
            image = sitk.ReadImage(grouped_files[df_name][pic])
            rescaled_image = rescale_images(image=image)
            image_array = sitk.GetArrayFromImage(rescaled_image)
            scaled = scaler.fit_transform(image_array[0, :, :])
            sns.histplot(scaled.flatten(), kde=True, alpha=0.3)
    elif scaler == 'robust':
        scaler = RobustScaler()
        plt.title(f"Histogram of Intensity for {df_name} (Robust)")
        for pic in range(numbers):
            image = sitk.ReadImage(grouped_files[df_name][pic])
            rescaled_image = rescale_images(image=image)
            image_array = sitk.GetArrayFromImage(rescaled_image)
            scaled = scaler.fit_transform(image_array[0, :, :])
            sns.histplot(scaled.flatten(), kde=True, alpha=0.3)
    elif scaler == 'maxabs':
        scaler = MaxAbsScaler()
        plt.title(f"Histogram of Intensity for {df_name} (maxabs)")
        for pic in range(numbers):
            image = sitk.ReadImage(grouped_files[df_name][pic])
            rescaled_image = rescale_images(image=image)
            image_array = sitk.GetArrayFromImage(rescaled_image)
            scaled = scaler.fit_transform(image_array[0, :, :])
            sns.histplot(scaled.flatten(), kde=True, alpha=0.3)
    elif scaler == 'normalize':
        plt.title(f"Histogram of Intensity for {df_name} (normalize)")
        for pic in range(numbers):
            image = sitk.ReadImage(grouped_files[df_name][pic])
            rescaled_image = rescale_images(image=image)
            scaled = sitk.Normalize(rescaled_image)
            scaled = sitk.GetArrayFromImage(scaled)
            sns.histplot(scaled[0, :, :].flatten(), kde=True, alpha=0.3)
    plt.legend(range(numbers))
    plt.xlabel("Intensity")
    plt.tight_layout()
    plt.show()

# %%
show_hist_intensity('t2w', 5)
# show_hist_intensity('t2w', 5,scaler='standard')
# show_hist_intensity('t2w', 5,scaler='minmax')
# show_hist_intensity('t2w', 5,scaler='robust')
# show_hist_intensity('t2w', 5,scaler='maxabs')
show_hist_intensity('t2w', 5, scaler='normalize')

# %%
def rescaler(df_name: str, df: object):
    os.makedirs("Dataset_v2", exist_ok=True)
    dir = list()
    for image in grouped_files[f'{df_name}']:
        re_image = rescale_images(sitk.ReadImage(image))
        re_image = sitk.Normalize(re_image)
        sitk.WriteImage(image=re_image, fileName=f'Dataset_v2/{image.split('/')[-1]}')
        dir.append(f'Dataset_v2/{image.split('/')[-1]}')
    df['path'] = dir

# %%
rescaler('adc', df_adc)
rescaler('sag', df_sag)
rescaler('cor', df_cor)
rescaler('t2w', df_t2w)
rescaler('hbv', df_hbv)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("After Scale")
plt.imshow(sitk.GetArrayFromImage(sitk.ReadImage(df_t2w['path'].iloc[0]))[0], cmap='gray')
plt.subplot(1, 2, 2)
plt.title("Before Scale")
plt.imshow(sitk.GetArrayFromImage(sitk.ReadImage(grouped_files['t2w'][0]))[0], cmap='gray')
plt.tight_layout()
plt.show()

# %%
def change_size(df):
    for pic in range(len(df['path'])):
        image = sitk.ReadImage(df['path'].iloc[pic])

        new_size = [256, 256, image.GetDepth()]

        original_size = image.GetSize()
        original_spacing = image.GetSpacing()

        new_spacing = [
            original_spacing[0] * (original_size[0] / new_size[0]),
            original_spacing[1] * (original_size[1] / new_size[1]),
            original_spacing[2]
        ]

        resample = sitk.ResampleImageFilter()
        resample.SetOutputSpacing(new_spacing)
        resample.SetSize(new_size)
        resample.SetInterpolator(sitk.sitkLinear)
        resample.SetOutputDirection(image.GetDirection())
        resample.SetOutputOrigin(image.GetOrigin())
        resample.SetDefaultPixelValue(0)

        resampled_image = resample.Execute(image)
        sitk.WriteImage(resampled_image, f'Dataset_v2/{df['path'].iloc[pic].split('/')[-1]}')

# %%
change_size(df_adc)
change_size(df_t2w)
change_size(df_cor)
change_size(df_hbv)
change_size(df_sag)

# %%
imge = sitk.ReadImage(df_adc['path'].iloc[0])
image_arr = sitk.GetArrayFromImage(imge)
plt.figure(figsize=(10, 5))
plt.title("After change size")
plt.imshow(image_arr[10], cmap='gray')
plt.show()
imge.GetSize()
# Out:
# (256, 256, 21)

# %% [markdown]
# ## Noise Handling and Contrast Enhancement

# %%
imge = sitk.ReadImage(df_t2w['path'].iloc[70]) #df_sag, df_cor, df_t2w
sharpen_filter = sitk.LaplacianSharpeningImageFilter()
sharped_image = sharpen_filter.Execute(imge)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Sharped image")
plt.imshow(sitk.GetArrayFromImage(sharped_image)[11], cmap='gray')
plt.subplot(1, 2, 2)
plt.title("original image")
plt.imshow(sitk.GetArrayFromImage(imge)[11], cmap='gray')
plt.show()

# %%
imge = sitk.ReadImage(df_hbv['path'].iloc[5]) # df_adc, df_hbv
median_filter = sitk.MedianImageFilter()
median_filter.SetRadius(1)
median_image = median_filter.Execute(imge)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Sharped image")
plt.imshow(sitk.GetArrayFromImage(median_image)[11], cmap='gray')
plt.subplot(1, 2, 2)
plt.title("original image")
plt.imshow(sitk.GetArrayFromImage(imge)[11], cmap='gray')
plt.show()

# %%
df_adc['path'].iloc[2]
# Out:
# 'Dataset_v2/10020_1000020_adc.mha'

# %%
clahe_filter = sitk.AdaptiveHistogramEqualizationImageFilter()
clahe_filter.SetAlpha(0.5)
clahe_filter.SetBeta(0.5)
enhanced_image = clahe_filter.Execute(median_image)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("enhanced image")
plt.imshow(sitk.GetArrayFromImage(enhanced_image)[11], cmap='gray')
plt.subplot(1, 2, 2)
plt.title("median image")
plt.imshow(sitk.GetArrayFromImage(median_image)[11], cmap='gray')
plt.show()

# %%
imge = sitk.ReadImage(df_t2w['path'].iloc[5]) #df_sag, df_cor, df_t2w
clahe_filter.SetAlpha(0)
clahe_filter.SetBeta(2)
enhanced_image = clahe_filter.Execute(imge)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Contrast image")
plt.imshow(sitk.GetArrayFromImage(enhanced_image)[10], cmap='gray')
plt.subplot(1, 2, 2)
plt.title("original image")
plt.imshow(sitk.GetArrayFromImage(imge)[10], cmap='gray')
plt.show()

# %%
def sharpen_image(df):
    os.makedirs('Dataset_v3', exist_ok=True)
    dir = list()
    for pic in range(len(df['path'])):
        image = sitk.ReadImage(df['path'].iloc[pic])
        sharpen_filter = sitk.LaplacianSharpeningImageFilter()
        sharpened_image = sharpen_filter.Execute(image)
        sitk.WriteImage(sharpened_image, f'Dataset_v3/{df["path"].iloc[pic].split("/")[-1]}')
        dir.append(f'Dataset_v3/{df['path'].iloc[pic].split('/')[-1]}')
    df['path'] = dir

# %%
def median_image(df):
    os.makedirs('Dataset_v3', exist_ok=True)
    dir = list()
    for pic in range(len(df['path'])):
        image = sitk.ReadImage(df['path'].iloc[pic])
        median_filter = sitk.MedianImageFilter()
        median_filter.SetRadius(1)
        median_image = median_filter.Execute(image)
        os.makedirs('Dataset_v3', exist_ok=True)
        sitk.WriteImage(median_image, f'Dataset_v3/{df["path"].iloc[pic].split("/")[-1]}')
        dir.append(f'Dataset_v3/{df['path'].iloc[pic].split('/')[-1]}')
    df['path'] = dir

# %%
def ahe(df):
    os.makedirs('Dataset_v3', exist_ok=True)
    for pic in range(len(df['path'])):
        image = sitk.ReadImage(df['path'].iloc[pic])
        ahe_filter = sitk.AdaptiveHistogramEqualizationImageFilter()
        ahe_filter.SetAlpha(0.5)
        ahe_filter.SetBeta(1)
        ahe_filter.SetRadius(3)
        enhanced_image = ahe_filter.Execute(image)
        sitk.WriteImage(enhanced_image, f'Dataset_v3/{df["path"].iloc[pic].split("/")[-1]}')

# %%
sharpen_image(df_t2w)
sharpen_image(df_sag)
sharpen_image(df_cor)

# %%
median_image(df_adc)
median_image(df_hbv)

# %%
ahe(df_t2w)
ahe(df_sag)
ahe(df_cor)
ahe(df_adc)
ahe(df_hbv)

# %% [markdown]
# ## Segmentation

# %%
image = sitk.ReadImage(df_hbv['path'].iloc[10])
threshold = sitk.HuangThresholdImageFilter()
threshold.SetInsideValue(0)
threshold.SetOutsideValue(1)
threshold.SetNumberOfHistogramBins(5)
seg = threshold.Execute(image)

seg_array = sitk.GetArrayFromImage(seg)
plt.imshow(seg_array[10, :, :], cmap='gray')
plt.show()
print(threshold.GetThreshold())
# Out:
# -0.7818544682998572

# %%
image = sitk.ReadImage(df_hbv['path'].iloc[10])
threshold = sitk.OtsuThresholdImageFilter()
threshold.SetInsideValue(0)
threshold.SetOutsideValue(1)
seg = threshold.Execute(image)

seg_array = sitk.GetArrayFromImage(seg)
image_array = sitk.GetArrayFromImage(image)
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(seg_array[10, :, :], cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(image_array[10, :, :], cmap='gray')
plt.tight_layout()
plt.show()
print(threshold.GetThreshold())
# Out:
# 0.6121142330627527

# %%
def segment(df):
    os.makedirs('Dataset_segments', exist_ok=True)
    for pic in range(len(df['path'])):
        image = sitk.ReadImage(df['path'].iloc[pic])
        threshold = sitk.OtsuThresholdImageFilter()
        threshold.SetInsideValue(0)
        threshold.SetOutsideValue(1)
        seg = threshold.Execute(image)
        sitk.WriteImage(seg, f'Dataset_segments/{df['path'].iloc[pic].split("/")[-1]}')

# %%
segment(df_adc)
segment(df_cor)
segment(df_sag)
segment(df_t2w)
segment(df_hbv)

# %%
segment = sitk.ReadImage('Dataset_segments/10001_1000001_hbv.mha')
seg_arr = sitk.GetArrayFromImage(segment)
plt.imshow(seg_arr[10, :, :], cmap='gray')
plt.tight_layout()
plt.show()

# %%
segment = sitk.ReadImage('Dataset_segments/10001_1000001_adc.mha')
sitk.Cast(segment, sitk.sitkFloat64)
seg_arr = sitk.GetArrayFromImage(segment)
plt.imshow(seg_arr[10, :, :], cmap='gray')
plt.tight_layout()
plt.show()

# %%
fixed_image = sitk.ReadImage(df_adc['path'].iloc[2])
moving_image = sitk.ReadImage(df_adc['path'].iloc[0])

registration_method = sitk.ImageRegistrationMethod()

registration_method.SetMetricAsMattesMutualInformation()

registration_method.SetOptimizerAsGradientDescent(learningRate=0.1, numberOfIterations=200)

transform = sitk.CenteredTransformInitializer(
    fixed_image, moving_image, sitk.Euler3DTransform(), sitk.CenteredTransformInitializerFilter.GEOMETRY
)

registration_method.SetInitialTransform(transform, inPlace=False)

final_transform = registration_method.Execute(fixed_image, moving_image)

moving_resampled = sitk.Resample(moving_image, fixed_image, final_transform, sitk.sitkLinear, 0.0, moving_image.GetPixelID())

def show_images(image1, image2, image3, title1="Fixed Image", title2="Registered Image", title3="Moving Image"):
    arr1 = sitk.GetArrayViewFromImage(image1)
    arr2 = sitk.GetArrayViewFromImage(image2)
    arr3 = sitk.GetArrayViewFromImage(image3)

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 3, 1)
    plt.imshow(arr1[10], cmap="gray")
    plt.title(title1)
    
    plt.subplot(1, 3, 2)
    plt.imshow(arr2[10], cmap="gray")
    plt.title(title2)
    
    plt.subplot(1, 3, 3)
    plt.imshow(arr3[10], cmap="gray")
    plt.title(title3)
    
    plt.show()

show_images(fixed_image, moving_resampled, moving_image)

# %%
def registration(df):
    os.makedirs('Dataset_registration', exist_ok=True)
    fixed_image = sitk.ReadImage(df['path'].iloc[2])
    for pic in range(len(df['path'])):
        if pic == 2:
            continue
        moving_image = sitk.ReadImage(df['path'].iloc[pic])
        registration_method = sitk.ImageRegistrationMethod()
        registration_method.SetMetricAsMattesMutualInformation()
        registration_method.SetOptimizerAsGradientDescent(learningRate=0.1, numberOfIterations=200)
        transform = sitk.CenteredTransformInitializer(
            fixed_image, moving_image, sitk.Euler3DTransform(), sitk.CenteredTransformInitializerFilter.GEOMETRY
        )
        registration_method.SetInitialTransform(transform, inPlace=False)
        final_transform = registration_method.Execute(fixed_image, moving_image)
        moving_resampled = sitk.Resample(moving_image, fixed_image, final_transform, sitk.sitkLinear, 0.0, moving_image.GetPixelID())
        sitk.WriteImage(moving_resampled, f'Dataset_registration/{df["path"].iloc[pic].split("/")[-1]}')
    sitk.WriteImage(fixed_image, f'Dataset_registration/{df["path"].iloc[2].split("/")[-1]}')

# %%
registration(df_adc)
registration(df_cor)
registration(df_sag)
registration(df_t2w)
registration(df_hbv)

# %%
def path_changer(df):
    l1 = list()
    l2 = list()
    for i in range(len(df['path'])):
        l1.append(f'Dataset_registration/{df["path"].iloc[i].split("/")[-1]}')
        l2.append(f'Dataset_segments/{df["path"].iloc[i].split("/")[-1]}')
    df['path_register'] = l1
    df['path_segment'] = l2

# %%
path_changer(df_adc)
path_changer(df_cor)
path_changer(df_sag)
path_changer(df_t2w)
path_changer(df_hbv)

# %% [markdown]
# ## Cropping

# %%
image = sitk.ReadImage(df_adc['path_register'].iloc[2])
cropped_image = sitk.Crop(image, [80, 80, 0], [80, 50, 0])
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(sitk.GetArrayFromImage(image)[10], cmap='gray')
plt.subplot(1, 2, 2)
plt.title("Cropped Image")
plt.imshow(sitk.GetArrayFromImage(cropped_image)[10], cmap='gray')
plt.show()

# %%
const = sitk.GetArrayFromImage(image)[2].max()
pad_x = (256 - cropped_image.GetSize()[0]) // 2
pad_y = (256 - cropped_image.GetSize()[1]) // 2

pad_image = sitk.ConstantPad(cropped_image, 
                             [pad_x, pad_y, 0], 
                             [pad_x, pad_y, 0], 
                             constant=const)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Cropped Image")
plt.imshow(sitk.GetArrayFromImage(cropped_image)[10], cmap='gray')
plt.subplot(1, 2, 2)
plt.title("Padded Image")
plt.imshow(sitk.GetArrayFromImage(pad_image)[10], cmap='gray')
plt.show()

# %%
pad_image.GetSize()
# Out:
# (256, 256, 21)

# %%
def cropping(df):
    os.makedirs('Dataset_croped', exist_ok=True)
    for pic in range(len(df['path_register'])):
        image = sitk.ReadImage(df['path_register'].iloc[pic])
        cropped_image = sitk.Crop(image, [80, 80, 0], [80, 50, 0])
        const = sitk.GetArrayFromImage(image)[10].max()
        pad_x = (256 - cropped_image.GetSize()[0]) // 2
        pad_y = (256 - cropped_image.GetSize()[1]) // 2
        pad_image = sitk.ConstantPad(cropped_image, 
                                     [pad_x, pad_y, 0], 
                                     [pad_x, pad_y, 0], 
                                     constant=const)
        sitk.WriteImage(pad_image, f'Dataset_croped/{df["path_register"].iloc[pic].split("/")[-1]}')
        df['path_final'] = f'Dataset_croped/{df["path_register"].iloc[pic].split("/")[-1]}'

# %%
cropping(df_adc)
cropping(df_cor)
cropping(df_sag)
cropping(df_t2w)
cropping(df_hbv)

# %% [markdown]
# ## Make Dataset

# %%
df_adc.to_csv('df_adc.csv')
df_cor.to_csv('df_cor.csv')
df_sag.to_csv('df_sag.csv')
df_t2w.to_csv('df_t2w.csv')
df_hbv.to_csv('df_hbv.csv')
